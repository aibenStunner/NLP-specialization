# %% [markdown]
# # CycleGAN

# %% [markdown]
# ### Goals
# In this notebook, you will write a generative model based on the paper [*Unpaired Image-to-Image Translation
# using Cycle-Consistent Adversarial Networks*](https://arxiv.org/abs/1703.10593) by Zhu et al. 2017, commonly referred to as CycleGAN.
#
# You will be training a model that can convert horses into zebras, and vice versa. Once again, the emphasis of the assignment will be on the loss functions. In order for you to see good outputs more quickly, you'll be training your model starting from a pre-trained checkpoint. You are also welcome to train it from scratch on your own, if you so choose.
#
#
# <!-- You will take the segmentations that you generated in the previous assignment and produce photorealistic images. -->
#
# ### Learning Objectives
# 1.   Implement the loss functions of a CycleGAN model.
# 2.   Observe the two GANs used in CycleGAN.

# %% [markdown]
# ## Getting Started
# You will start by importing libraries, defining a visualization function, and getting the pre-trained CycleGAN checkpoint.

# %%
import torch
from torch import nn
from tqdm.auto import tqdm
from torchvision import transforms
from torchvision.utils import make_grid
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
torch.manual_seed(0)

def show_tensor_images(image_tensor, num_images=25, size=(1, 28, 28)):
    '''
    Function for visualizing images: Given a tensor of images, number of images, and
    size per image, plots and prints the images in an uniform grid.
    '''
    image_tensor = (image_tensor + 1) / 2
    image_shifted = image_tensor
    image_unflat = image_shifted.detach().cpu().view(-1, *size)
    image_grid = make_grid(image_unflat[:num_images], nrow=5)
    plt.imshow(image_grid.permute(1, 2, 0).squeeze())
    plt.show()


import glob
import random
import os
from torch.utils.data import Dataset
from PIL import Image

# Inspired by https://github.com/aitorzip/PyTorch-CycleGAN/blob/master/datasets.py
class ImageDataset(Dataset):
    def __init__(self, root, transform=None, mode='train'):
        self.transform = transform
        self.files_A = sorted(glob.glob(os.path.join(root, '%sA' % mode) + '/*.*'))
        self.files_B = sorted(glob.glob(os.path.join(root, '%sB' % mode) + '/*.*'))
        if len(self.files_A) > len(self.files_B):
            self.files_A, self.files_B = self.files_B, self.files_A
        self.new_perm()
        assert len(self.files_A) > 0, "Make sure you downloaded the horse2zebra images!"

    def new_perm(self):
        self.randperm = torch.randperm(len(self.files_B))[:len(self.files_A)]

    def __getitem__(self, index):
        item_A = self.transform(Image.open(self.files_A[index % len(self.files_A)]))
        item_B = self.transform(Image.open(self.files_B[self.randperm[index]]))
        if item_A.shape[0] != 3: 
            item_A = item_A.repeat(3, 1, 1)
        if item_B.shape[0] != 3: 
            item_B = item_B.repeat(3, 1, 1)
        if index == len(self) - 1:
            self.new_perm()
        # Old versions of PyTorch didn't support normalization for different-channeled images
        return (item_A - 0.5) * 2, (item_B - 0.5) * 2

    def __len__(self):
        return min(len(self.files_A), len(self.files_B))

# %% [markdown]
# ## Generator
# The code for a CycleGAN generator is much like Pix2Pix's U-Net with the addition of the residual block between the encoding (contracting) and decoding (expanding) blocks.
#
# ![Diagram of a CycleGAN generator: composed of encoding blocks, residual blocks, then decoding blocks](https://drive.google.com/uc?id=1K7fCr6lXzxn9LCUvKl0ozXthz2I9FZSv)
# *Diagram of a CycleGAN generator: composed of encoding blocks, residual blocks, and then decoding blocks.*

# %% [markdown]
# #### Residual Block
# Perhaps the most notable architectural difference between the U-Net you used for Pix2Pix and the architecture you're using for CycleGAN are the residual blocks. In CycleGAN, after the expanding blocks, there are convolutional layers where the output is ultimately added to the original input so that the network can change as little as possible on the image. You can think of this transformation as a kind of skip connection, where instead of being concatenated as new channels before the convolution which combines them, it's added directly to the output of the convolution. In the visualization below, you can imagine the stripes being generated by the convolutions and then added to the original image of the horse to transform it into a zebra. These skip connections also allow the network to be deeper, because they help with vanishing gradients issues that come when a neural network gets too deep and the gradients multiply in backpropagation to become very small; instead, these skip connections enable more gradient flow. A deeper network is often able to learn more complex features.
#
#
# ![Residual block explanation: shows horse going through convolutions leading to stripes, added to the original horse image to get a zebra](https://drive.google.com/uc?id=1T-oic1q-wi-Hj4yeWb4r8sl_9laq58wm&)
#
# *Example of a residual block.*

# %%
class ResidualBlock(nn.Module):
    '''
    ResidualBlock Class:
    Performs two convolutions and an instance normalization, the input is added
    to this output to form the residual block output.
    Values:
        input_channels: the number of channels to expect from a given input
    '''
    def __init__(self, input_channels):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(input_channels, input_channels, kernel_size=3, padding=1, padding_mode='reflect')
        self.conv2 = nn.Conv2d(input_channels, input_channels, kernel_size=3, padding=1, padding_mode='reflect')
        self.instancenorm = nn.InstanceNorm2d(input_channels)
        self.activation = nn.ReLU()

    def forward(self, x):
        '''
        Function for completing a forward pass of ResidualBlock: 
        Given an image tensor, completes a residual block and returns the transformed tensor.
        Parameters:
            x: image tensor of shape (batch size, channels, height, width)
        '''
        original_x = x.clone()
        x = self.conv1(x)
        x = self.instancenorm(x)
        x = self.activation(x)
        x = self.conv2(x)
        x = self.instancenorm(x)
        return original_x + x

# %% [markdown]
# #### Contracting and Expanding Blocks
#
# The rest of the generator code will otherwise be much like the code you wrote for the last assignment: Pix2Pix's U-Net. The primary changes are the use of instance norm instead of batch norm (which you may recall from StyleGAN), no dropout, and a stride-2 convolution instead of max pooling. Feel free to investigate the code if you're interested!

# %%
class ContractingBlock(nn.Module):
    '''
    ContractingBlock Class
    Performs a convolution followed by a max pool operation and an optional instance norm.
    Values:
        input_channels: the number of channels to expect from a given input
    '''
    def __init__(self, input_channels, use_bn=True, kernel_size=3, activation='relu'):
        super(ContractingBlock, self).__init__()
        self.conv1 = nn.Conv2d(input_channels, input_channels * 2, kernel_size=kernel_size, padding=1, stride=2, padding_mode='reflect')
        self.activation = nn.ReLU() if activation == 'relu' else nn.LeakyReLU(0.2)
        if use_bn:
            self.instancenorm = nn.InstanceNorm2d(input_channels * 2)
        self.use_bn = use_bn

    def forward(self, x):
        '''
        Function for completing a forward pass of ContractingBlock: 
        Given an image tensor, completes a contracting block and returns the transformed tensor.
        Parameters:
            x: image tensor of shape (batch size, channels, height, width)
        '''
        x = self.conv1(x)
        if self.use_bn:
            x = self.instancenorm(x)
        x = self.activation(x)
        return x

class ExpandingBlock(nn.Module):
    '''
    ExpandingBlock Class:
    Performs a convolutional transpose operation in order to upsample, 
        with an optional instance norm
    Values:
        input_channels: the number of channels to expect from a given input
    '''
    def __init__(self, input_channels, use_bn=True):
        super(ExpandingBlock, self).__init__()
        self.conv1 = nn.ConvTranspose2d(input_channels, input_channels // 2, kernel_size=3, stride=2, padding=1, output_padding=1)
        if use_bn:
            self.instancenorm = nn.InstanceNorm2d(input_channels // 2)
        self.use_bn = use_bn
        self.activation = nn.ReLU()

    def forward(self, x):
        '''
        Function for completing a forward pass of ExpandingBlock: 
        Given an image tensor, completes an expanding block and returns the transformed tensor.
        Parameters:
            x: image tensor of shape (batch size, channels, height, width)
            skip_con_x: the image tensor from the contracting path (from the opposing block of x)
                    for the skip connection
        '''
        x = self.conv1(x)
        if self.use_bn:
            x = self.instancenorm(x)
        x = self.activation(x)
        return x

class FeatureMapBlock(nn.Module):
    '''
    FeatureMapBlock Class
    The final layer of a Generator - 
    maps each the output to the desired number of output channels
    Values:
        input_channels: the number of channels to expect from a given input
        output_channels: the number of channels to expect for a given output
    '''
    def __init__(self, input_channels, output_channels):
        super(FeatureMapBlock, self).__init__()
        self.conv = nn.Conv2d(input_channels, output_channels, kernel_size=7, padding=3, padding_mode='reflect')

    def forward(self, x):
        '''
        Function for completing a forward pass of FeatureMapBlock: 
        Given an image tensor, returns it mapped to the desired number of channels.
        Parameters:
            x: image tensor of shape (batch size, channels, height, width)
        '''
        x = self.conv(x)
        return x

# %% [markdown]
# #### CycleGAN Generator
# Finally, you can put all the blocks together to create your CycleGAN generator.

# %%
class Generator(nn.Module):
    '''
    Generator Class
    A series of 2 contracting blocks, 9 residual blocks, and 2 expanding blocks to 
    transform an input image into an image from the other class, with an upfeature
    layer at the start and a downfeature layer at the end.
    Values:
        input_channels: the number of channels to expect from a given input
        output_channels: the number of channels to expect for a given output
    '''
    def __init__(self, input_channels, output_channels, hidden_channels=64):
        super(Generator, self).__init__()
        self.upfeature = FeatureMapBlock(input_channels, hidden_channels)
        self.contract1 = ContractingBlock(hidden_channels)
        self.contract2 = ContractingBlock(hidden_channels * 2)
        res_mult = 4
        self.res0 = ResidualBlock(hidden_channels * res_mult)
        self.res1 = ResidualBlock(hidden_channels * res_mult)
        self.res2 = ResidualBlock(hidden_channels * res_mult)
        self.res3 = ResidualBlock(hidden_channels * res_mult)
        self.res4 = ResidualBlock(hidden_channels * res_mult)
        self.res5 = ResidualBlock(hidden_channels * res_mult)
        self.res6 = ResidualBlock(hidden_channels * res_mult)
        self.res7 = ResidualBlock(hidden_channels * res_mult)
        self.res8 = ResidualBlock(hidden_channels * res_mult)
        self.expand2 = ExpandingBlock(hidden_channels * 4)
        self.expand3 = ExpandingBlock(hidden_channels * 2)
        self.downfeature = FeatureMapBlock(hidden_channels, output_channels)
        self.tanh = torch.nn.Tanh()

    def forward(self, x):
        '''
        Function for completing a forward pass of Generator: 
        Given an image tensor, passes it through the U-Net with residual blocks
        and returns the output.
        Parameters:
            x: image tensor of shape (batch size, channels, height, width)
        '''
        x0 = self.upfeature(x)
        x1 = self.contract1(x0)
        x2 = self.contract2(x1)
        x3 = self.res0(x2)
        x4 = self.res1(x3)
        x5 = self.res2(x4)
        x6 = self.res3(x5)
        x7 = self.res4(x6)
        x8 = self.res5(x7)
        x9 = self.res6(x8)
        x10 = self.res7(x9)
        x11 = self.res8(x10)
        x12 = self.expand2(x11)
        x13 = self.expand3(x12)
        xn = self.downfeature(x13)
        return self.tanh(xn)

# %% [markdown]
# ## PatchGAN Discriminator
#
# Next, you will define the discriminator—a PatchGAN. It will be very similar to what you saw in Pix2Pix.

# %%
class Discriminator(nn.Module):
    '''
    Discriminator Class
    Structured like the contracting path of the U-Net, the discriminator will
    output a matrix of values classifying corresponding portions of the image as real or fake. 
    Parameters:
        input_channels: the number of image input channels
        hidden_channels: the initial number of discriminator convolutional filters
    '''
    def __init__(self, input_channels, hidden_channels=64):
        super(Discriminator, self).__init__()
        self.upfeature = FeatureMapBlock(input_channels, hidden_channels)
        self.contract1 = ContractingBlock(hidden_channels, use_bn=False, kernel_size=4, activation='lrelu')
        self.contract2 = ContractingBlock(hidden_channels * 2, kernel_size=4, activation='lrelu')
        self.contract3 = ContractingBlock(hidden_channels * 4, kernel_size=4, activation='lrelu')
        self.final = nn.Conv2d(hidden_channels * 8, 1, kernel_size=1)

    def forward(self, x):
        x0 = self.upfeature(x)
        x1 = self.contract1(x0)
        x2 = self.contract2(x1)
        x3 = self.contract3(x2)
        xn = self.final(x3)
        return xn

# %% [markdown]
# ## Training Preparation
# <!-- You'll be using the same U-Net as in the previous assignment, but you'll write another discriminator and change the loss to make it a GAN. -->
#
# Now you can put everything together for training! You will start by defining your parameters:
#
#   *   adv_criterion: an adversarial loss function to keep track of how well the GAN is fooling the discriminator and how well the discriminator is catching the GAN
#   *   recon_criterion: a loss function that rewards similar images to the ground truth, which "reconstruct" the image
#   *   n_epochs: the number of times you iterate through the entire dataset when training
#   *   dim_A: the number of channels of the images in pile A
#   *   dim_B: the number of channels of the images in pile B (note that in the visualization this is currently treated as equivalent to dim_A)
#   *   display_step: how often to display/visualize the images
#   *   batch_size: the number of images per forward/backward pass
#   *   lr: the learning rate
#   *   target_shape: the size of the input and output images (in pixels)
#   *   load_shape: the size for the dataset to load the images at before randomly cropping them to target_shape as a simple data augmentation
#   *   device: the device type

# %%
import torch.nn.functional as F

adv_criterion = nn.MSELoss() 
recon_criterion = nn.L1Loss() 

n_epochs = 20
dim_A = 3
dim_B = 3
display_step = 200
batch_size = 1
lr = 0.0002
load_shape = 286
target_shape = 256
device = 'cuda'

# %% [markdown]
# You will then load the images of the dataset while introducing some data augmentation (e.g. crops and random horizontal flips).

# %%
transform = transforms.Compose([
    transforms.Resize(load_shape),
    transforms.RandomCrop(target_shape),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

import torchvision
dataset = ImageDataset("horse2zebra", transform=transform)

# %% [markdown]
# Next, you can initialize your generators and discriminators, as well as their optimizers. For CycleGAN, you will have two generators and two discriminators since there are two GANs:
#
# *   Generator for horse to zebra (`gen_AB`)
# *   Generator for zebra to horse (`gen_BA`)
# *   Discriminator for horse (`disc_A`)
# *   Discriminator for zebra (`disc_B`)
#
# You will also load your pre-trained model.

# %%
gen_AB = Generator(dim_A, dim_B).to(device)
gen_BA = Generator(dim_B, dim_A).to(device)
gen_opt = torch.optim.Adam(list(gen_AB.parameters()) + list(gen_BA.parameters()), lr=lr, betas=(0.5, 0.999))
disc_A = Discriminator(dim_A).to(device)
disc_A_opt = torch.optim.Adam(disc_A.parameters(), lr=lr, betas=(0.5, 0.999))
disc_B = Discriminator(dim_B).to(device)
disc_B_opt = torch.optim.Adam(disc_B.parameters(), lr=lr, betas=(0.5, 0.999))

def weights_init(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        torch.nn.init.normal_(m.weight, 0.0, 0.02)
    if isinstance(m, nn.BatchNorm2d):
        torch.nn.init.normal_(m.weight, 0.0, 0.02)
        torch.nn.init.constant_(m.bias, 0)

# Feel free to change pretrained to False if you're training the model from scratch
pretrained = True
if pretrained:
    pre_dict = torch.load('cycleGAN_100000.pth')
    gen_AB.load_state_dict(pre_dict['gen_AB'])
    gen_BA.load_state_dict(pre_dict['gen_BA'])
    gen_opt.load_state_dict(pre_dict['gen_opt'])
    disc_A.load_state_dict(pre_dict['disc_A'])
    disc_A_opt.load_state_dict(pre_dict['disc_A_opt'])
    disc_B.load_state_dict(pre_dict['disc_B'])
    disc_B_opt.load_state_dict(pre_dict['disc_B_opt'])
else:
    gen_AB = gen_AB.apply(weights_init)
    gen_BA = gen_BA.apply(weights_init)
    disc_A = disc_A.apply(weights_init)
    disc_B = disc_B.apply(weights_init)

# %% [markdown]
# ## Discriminator Loss
# First, you're going to be implementing the discriminator loss. This is the same as in previous assignments, so it should be a breeze :) Don't forget to detach your generator!

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: get_disc_loss
def get_disc_loss(real_X, fake_X, disc_X, adv_criterion):
    '''
    Return the loss of the discriminator given inputs.
    Parameters:
        real_X: the real images from pile X
        fake_X: the generated images of class X
        disc_X: the discriminator for class X; takes images and returns real/fake class X
            prediction matrices
        adv_criterion: the adversarial loss function; takes the discriminator 
            predictions and the target labels and returns a adversarial 
            loss (which you aim to minimize)
    '''
    #### START CODE HERE ####
    fake_X.detach()
    fake_pred = disc_X(fake_X)
    fake_loss = adv_criterion(fake_pred, torch.ones_like(fake_pred))
    real_pred = disc_X(real_X)
    real_loss = adv_criterion(real_pred, torch.zeros_like(real_pred))
    disc_loss = (real_loss+fake_loss) / 2.0
    
    #### END CODE HERE ####
    return disc_loss

# %%
# UNIT TEST
test_disc_X = lambda x: x * 97
test_real_X = torch.tensor(83.)
test_fake_X = torch.tensor(89.)
test_adv_criterion = lambda x, y: x * 79 + y * 73
assert torch.abs((get_disc_loss(test_real_X, test_fake_X, test_disc_X, test_adv_criterion)) - 659054.5000) < 1e-6
test_disc_X = lambda x: x.mean(0, keepdim=True)
test_adv_criterion = torch.nn.BCEWithLogitsLoss()
test_input = torch.ones(20, 10)
# If this runs, it's a pass - checks that the shapes are treated correctly
get_disc_loss(test_input, test_input, test_disc_X, test_adv_criterion)
print("Success!")
# Out:
# Success!

# %% [markdown]
# ## Generator Loss
# While there are some changes to the CycleGAN architecture from Pix2Pix, the most important distinguishing feature of CycleGAN is its generator loss. You will be implementing that here!

# %% [markdown]
# #### Adversarial Loss
# The first component of the generator's loss you're going to implement is its adversarial loss—this once again is pretty similar to the GAN loss that you've implemented in the past. The important thing to note is that the criterion now is based on least squares loss, rather than binary cross entropy loss or W-loss.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: get_gen_adversarial_loss
def get_gen_adversarial_loss(real_X, disc_Y, gen_XY, adv_criterion):
    '''
    Return the adversarial loss of the generator given inputs
    (and the generated images for testing purposes).
    Parameters:
        real_X: the real images from pile X
        disc_Y: the discriminator for class Y; takes images and returns real/fake class Y
            prediction matrices
        gen_XY: the generator for class X to Y; takes images and returns the images 
            transformed to class Y
        adv_criterion: the adversarial loss function; takes the discriminator 
                  predictions and the target labels and returns a adversarial 
                  loss (which you aim to minimize)
    '''
    #### START CODE HERE ####
    fake_Y = gen_XY(real_X)
    pred_Y = disc_Y(fake_Y)
    adversarial_loss = adv_criterion(pred_Y, torch.ones_like(pred_Y))
    
    #### END CODE HERE ####
    return adversarial_loss, fake_Y

# %%
# UNIT TEST
test_disc_Y = lambda x: x * 97
test_real_X = torch.tensor(83.)
test_gen_XY = lambda x: x * 89
test_adv_criterion = lambda x, y: x * 79 + y * 73
test_res = get_gen_adversarial_loss(test_real_X, test_disc_Y, test_gen_XY, test_adv_criterion)
assert torch.abs(test_res[0] - 56606652) < 1e-6
assert torch.abs(test_res[1] - 7387) < 1e-6
test_disc_Y = lambda x: x.mean(0, keepdim=True)
test_adv_criterion = torch.nn.BCEWithLogitsLoss()
test_input = torch.ones(20, 10)
# If this runs, it's a pass - checks that the shapes are treated correctly
get_gen_adversarial_loss(test_input, test_disc_Y, test_gen_XY, test_adv_criterion)
print("Success!")
# Out:
# Success!

# %% [markdown]
# #### Identity Loss
# Here you get to see some of the superbly new material! You'll want to measure the change in an image when you pass the generator an example from the target domain instead of the input domain it's expecting. The output should be the same as the input since it is already of the target domain class. For example, if you put a horse through a zebra -> horse generator, you'd expect the output to be the same horse because nothing needed to be transformed. It's already a horse! You don't want your generator to be transforming it into any other thing, so you want to encourage this behavior. In encouraging this identity mapping, the authors of CycleGAN found that for some tasks, this helped properly preserve the colors of an image, even when the expected input (here, a zebra) was put in. This was particularly useful for the photos <-> paintings mapping and, while an optional aesthetic component, you might find it useful for your applications down the line.
#
# ![Diagram showing a real horse image going through a zebra -> horse generator and the ideal output being the same input image](https://drive.google.com/uc?id=19cO4sawwlNNbnyh-jZCTWFSRd6mfrary)

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: get_identity_loss
def get_identity_loss(real_X, gen_YX, identity_criterion):
    '''
    Return the identity loss of the generator given inputs
    (and the generated images for testing purposes).
    Parameters:
        real_X: the real images from pile X
        gen_YX: the generator for class Y to X; takes images and returns the images 
            transformed to class X
        identity_criterion: the identity loss function; takes the real images from X and
                        those images put through a Y->X generator and returns the identity 
                        loss (which you aim to minimize)
    '''
    #### START CODE HERE ####
    identity_X = gen_YX(real_X)
    identity_loss = identity_criterion(real_X, identity_X)
    
    #### END CODE HERE ####
    return identity_loss, identity_X

# %%
# UNIT TEST
test_real_X = torch.tensor(83.)
test_gen_YX = lambda x: x * 89
test_identity_criterion = lambda x, y: (x + y) * 73
test_res = get_identity_loss(test_real_X, test_gen_YX, test_identity_criterion)
assert torch.abs(test_res[0] - 545310) < 1e-6
assert torch.abs(test_res[1] - 7387) < 1e-6
print("Success!")
# Out:
# Success!

# %% [markdown]
# #### Cycle Consistency Loss
# Now, you can implement the final generator loss and the part that puts the "cycle" in CycleGAN: cycle consistency loss. This is used to ensure that when you put an image through one generator, that if it is then transformed back into the input class using the opposite generator, the image is the same as the original input image.
#
# ![Diagram showing a real zebra image being transformed into a horse and then back into a zebra. The output zebra should be the same as the input zebra.](https://drive.google.com/uc?id=1bg8w_LGMLcVJEMdA4kyUr5UqxxtySTDq)
#
# Since you've already generated a fake image for the adversarial part, you can pass that fake image back to produce a full cycle—this loss will encourage the cycle to preserve as much information as possible.
#
# *Fun fact: Cycle consistency is a broader concept that's used outside of CycleGAN a lot too! It's helped with data augmentation and has been used on text translation too, e.g. French -> English -> French should get the same phrase back.*

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: get_cycle_consistency_loss
def get_cycle_consistency_loss(real_X, fake_Y, gen_YX, cycle_criterion):
    '''
    Return the cycle consistency loss of the generator given inputs
    (and the generated images for testing purposes).
    Parameters:
        real_X: the real images from pile X
        fake_Y: the generated images of class Y
        gen_YX: the generator for class Y to X; takes images and returns the images 
            transformed to class X
        cycle_criterion: the cycle consistency loss function; takes the real images from X and
                        those images put through a X->Y generator and then Y->X generator
                        and returns the cycle consistency loss (which you aim to minimize)
    '''
    #### START CODE HERE ####
    cycle_X = gen_YX(fake_Y)
    cycle_loss = cycle_criterion(cycle_X, real_X)
    
    #### END CODE HERE ####
    return cycle_loss, cycle_X

# %%
# UNIT TEST
test_real_X = torch.tensor(83.)
test_fake_Y = torch.tensor(97.)
test_gen_YX = lambda x: x * 89
test_cycle_criterion = lambda x, y: (x + y) * 73
test_res = get_cycle_consistency_loss(test_real_X, test_fake_Y, test_gen_YX, test_cycle_criterion)
assert torch.abs(test_res[1] - 8633) < 1e-6
assert torch.abs(test_res[0] - 636268) < 1e-6
print("Success!")
# Out:
# Success!

# %% [markdown]
# #### Generator Loss (Total)
#
# Finally, you can put it all together! There are many components, so be careful as you go through this section.

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# GRADED FUNCTION: get_gen_loss
def get_gen_loss(real_A, real_B, gen_AB, gen_BA, disc_A, disc_B, adv_criterion, identity_criterion, cycle_criterion, lambda_identity=0.1, lambda_cycle=10):
    '''
    Return the loss of the generator given inputs.
    Parameters:
        real_A: the real images from pile A
        real_B: the real images from pile B
        gen_AB: the generator for class A to B; takes images and returns the images 
            transformed to class B
        gen_BA: the generator for class B to A; takes images and returns the images 
            transformed to class A
        disc_A: the discriminator for class A; takes images and returns real/fake class A
            prediction matrices
        disc_B: the discriminator for class B; takes images and returns real/fake class B
            prediction matrices
        adv_criterion: the adversarial loss function; takes the discriminator 
            predictions and the true labels and returns a adversarial 
            loss (which you aim to minimize)
        identity_criterion: the reconstruction loss function used for identity loss
            and cycle consistency loss; takes two sets of images and returns
            their pixel differences (which you aim to minimize)
        cycle_criterion: the cycle consistency loss function; takes the real images from X and
            those images put through a X->Y generator and then Y->X generator
            and returns the cycle consistency loss (which you aim to minimize).
            Note that in practice, cycle_criterion == identity_criterion == L1 loss
        lambda_identity: the weight of the identity loss
        lambda_cycle: the weight of the cycle-consistency loss
    '''
    # Hint 1: Make sure you include both directions - you can think of the generators as collaborating
    # Hint 2: Don't forget to use the lambdas for the identity loss and cycle loss!
    #### START CODE HERE ####
    # Adversarial Loss -- get_gen_adversarial_loss(real_X, disc_Y, gen_XY, adv_criterion)
    adversarial_loss, fake_B = get_gen_adversarial_loss(real_A, disc_B, gen_AB, adv_criterion)
    adversarial_loss_2, fake_A = get_gen_adversarial_loss(real_B, disc_A, gen_BA, adv_criterion)
    
    # Identity Loss -- get_identity_loss(real_X, gen_YX, identity_criterion)
    identity_loss, identity_A = get_identity_loss(real_A, gen_BA, identity_criterion)
    identity_loss_2, identity_B = get_identity_loss(real_B, gen_AB, identity_criterion)
    
    # Cycle-consistency Loss -- get_cycle_consistency_loss(real_X, fake_Y, gen_YX, cycle_criterion)
    cycle_loss, cycle_A = get_cycle_consistency_loss(real_A, fake_B, gen_BA, cycle_criterion)
    cycle_loss_2, cycle_B = get_cycle_consistency_loss(real_B, fake_A, gen_AB, cycle_criterion)
    
    # Total loss
    gen_loss = adversarial_loss + adversarial_loss_2 + lambda_identity * (identity_loss + identity_loss_2) +  lambda_cycle * (cycle_loss + cycle_loss_2)
    #### END CODE HERE ####
    return gen_loss, fake_A, fake_B

# %%
# UNIT TEST
test_real_A = torch.tensor(97)
test_real_B = torch.tensor(89)
test_gen_AB = lambda x: x * 83
test_gen_BA = lambda x: x * 79
test_disc_A = lambda x: x * 47
test_disc_B = lambda x: x * 43
test_adv_criterion = lambda x, y: x * 73 + y * 71
test_recon_criterion = lambda x, y: (x + y) * 61
test_lambda_identity = 59
test_lambda_cycle = 53
test_res = get_gen_loss(
    test_real_A, 
    test_real_B, 
    test_gen_AB, 
    test_gen_BA, 
    test_disc_A,
    test_disc_B,
    test_adv_criterion, 
    test_recon_criterion, 
    test_recon_criterion, 
    test_lambda_identity, 
    test_lambda_cycle)
assert test_res[0].item() == 4047804560
assert test_res[1].item() == 7031
assert test_res[2].item() == 8051
print("Success!")
# Out:
# Success!

# %% [markdown]
# ## CycleGAN Training
#
# Lastly, you can train the model and see some of your zebras, horses, and some that might not quite look like either! Note that this training will take a long time, so feel free to use the pre-trained checkpoint as an example of what a pretty-good CycleGAN does.

# %%
from skimage import color
import numpy as np
plt.rcParams["figure.figsize"] = (10, 10)


def train(save_model=False):
    mean_generator_loss = 0
    mean_discriminator_loss = 0
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
    cur_step = 0

    for epoch in range(n_epochs):
        # Dataloader returns the batches
        # for image, _ in tqdm(dataloader):
        for real_A, real_B in tqdm(dataloader):
            # image_width = image.shape[3]
            real_A = nn.functional.interpolate(real_A, size=target_shape)
            real_B = nn.functional.interpolate(real_B, size=target_shape)
            cur_batch_size = len(real_A)
            real_A = real_A.to(device)
            real_B = real_B.to(device)

            ### Update discriminator A ###
            disc_A_opt.zero_grad() # Zero out the gradient before backpropagation
            with torch.no_grad():
                fake_A = gen_BA(real_B)
            disc_A_loss = get_disc_loss(real_A, fake_A, disc_A, adv_criterion)
            disc_A_loss.backward(retain_graph=True) # Update gradients
            disc_A_opt.step() # Update optimizer

            ### Update discriminator B ###
            disc_B_opt.zero_grad() # Zero out the gradient before backpropagation
            with torch.no_grad():
                fake_B = gen_AB(real_A)
            disc_B_loss = get_disc_loss(real_B, fake_B, disc_B, adv_criterion)
            disc_B_loss.backward(retain_graph=True) # Update gradients
            disc_B_opt.step() # Update optimizer

            ### Update generator ###
            gen_opt.zero_grad()
            gen_loss, fake_A, fake_B = get_gen_loss(
                real_A, real_B, gen_AB, gen_BA, disc_A, disc_B, adv_criterion, recon_criterion, recon_criterion
            )
            gen_loss.backward() # Update gradients
            gen_opt.step() # Update optimizer

            # Keep track of the average discriminator loss
            mean_discriminator_loss += disc_A_loss.item() / display_step
            # Keep track of the average generator loss
            mean_generator_loss += gen_loss.item() / display_step

            ### Visualization code ###
            if cur_step % display_step == 0:
                print(f"Epoch {epoch}: Step {cur_step}: Generator (U-Net) loss: {mean_generator_loss}, Discriminator loss: {mean_discriminator_loss}")
                show_tensor_images(torch.cat([real_A, real_B]), size=(dim_A, target_shape, target_shape))
                show_tensor_images(torch.cat([fake_B, fake_A]), size=(dim_B, target_shape, target_shape))
                mean_generator_loss = 0
                mean_discriminator_loss = 0
                # You can change save_model to True if you'd like to save the model
                if save_model:
                    torch.save({
                        'gen_AB': gen_AB.state_dict(),
                        'gen_BA': gen_BA.state_dict(),
                        'gen_opt': gen_opt.state_dict(),
                        'disc_A': disc_A.state_dict(),
                        'disc_A_opt': disc_A_opt.state_dict(),
                        'disc_B': disc_B.state_dict(),
                        'disc_B_opt': disc_B_opt.state_dict()
                    }, f"cycleGAN_{cur_step}.pth")
            cur_step += 1
train()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1067.0), HTML(value='')))
# Epoch 0: Step 0: Generator (U-Net) loss: 0.009861667156219483, Discriminator loss: 0.0024821379780769347
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-f31be91e65f9> in <module>
#      69                     }, f"cycleGAN_{cur_step}.pth")
#      70             cur_step += 1
# ---> 71 train()
#
# <ipython-input-19-f31be91e65f9> in train(save_model)
#      42                 real_A, real_B, gen_AB, gen_BA, disc_A, disc_B, adv_criterion, recon_criterion, recon_criterion
#      43             )
# ---> 44             gen_loss.backward() # Update gradients
#      45             gen_opt.step() # Update optimizer
#      46
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
# !tar chvfz notebook.tar.gz *
# Out:
# C3W3_Assignment.ipynb
# cycleGAN_100000.pth
# horse2zebra/
# horse2zebra/trainB/
# horse2zebra/trainB/n02391049_6378.jpg
# horse2zebra/trainB/n02391049_9762.jpg
# horse2zebra/trainB/n02391049_10007.jpg
# horse2zebra/trainB/n02391049_4677.jpg
# horse2zebra/trainB/n02391049_602.jpg
# horse2zebra/trainB/n02391049_7188.jpg
# horse2zebra/trainB/n02391049_2895.jpg
# horse2zebra/trainB/n02391049_4839.jpg
# horse2zebra/trainB/n02391049_8394.jpg
# horse2zebra/trainB/n02391049_7584.jpg
# horse2zebra/trainB/n02391049_10322.jpg
# horse2zebra/trainB/n02391049_2024.jpg
# horse2zebra/trainB/n02391049_125.jpg
# horse2zebra/trainB/n02391049_9528.jpg
# horse2zebra/trainB/n02391049_2141.jpg
# horse2zebra/trainB/n02391049_404.jpg
# horse2zebra/trainB/n02391049_9726.jpg
# horse2zebra/trainB/n02391049_2222.jpg
# horse2zebra/trainB/n02391049_161.jpg
# horse2zebra/trainB/n02391049_879.jpg
# horse2zebra/trainB/n02391049_8178.jpg
# horse2zebra/trainB/n02391049_6396.jpg
# horse2zebra/trainB/n02391049_5586.jpg
# horse2zebra/trainB/n02391049_7368.jpg
# horse2zebra/trainB/n02391049_224.jpg
# horse2zebra/trainB/n02391049_7683.jpg
# horse2zebra/trainB/n02391049_1869.jpg
# horse2zebra/trainB/n02391049_699.jpg
# horse2zebra/trainB/n02391049_2204.jpg
# horse2zebra/trainB/n02391049_26.jpg
# horse2zebra/trainB/n02391049_5982.jpg
# horse2zebra/trainB/n02391049_4974.jpg
# horse2zebra/trainB/n02391049_6918.jpg
# horse2zebra/trainB/n02391049_7566.jpg
# horse2zebra/trainB/n02391049_107.jpg
# horse2zebra/trainB/n02391049_978.jpg
# horse2zebra/trainB/n02391049_2877.jpg
# horse2zebra/trainB/n02391049_2321.jpg
# horse2zebra/trainB/n02391049_6198.jpg
# horse2zebra/trainB/n02391049_341.jpg
# horse2zebra/trainB/n02391049_897.jpg
# horse2zebra/trainB/n02391049_2985.jpg
# horse2zebra/trainB/n02391049_611.jpg
# horse2zebra/trainB/n02391049_8565.jpg
# horse2zebra/trainB/n02391049_7836.jpg
# horse2zebra/trainB/n02391049_1223.jpg
# horse2zebra/trainB/n02391049_17.jpg
# horse2zebra/trainB/n02391049_9258.jpg
# horse2zebra/trainB/n02391049_4965.jpg
# horse2zebra/trainB/n02391049_1025.jpg
# horse2zebra/trainB/n02391049_7557.jpg
# horse2zebra/trainB/n02391049_969.jpg
# horse2zebra/trainB/n02391049_251.jpg
# horse2zebra/trainB/n02391049_3041.jpg
# horse2zebra/trainB/n02391049_2949.jpg
# horse2zebra/trainB/n02391049_332.jpg
# horse2zebra/trainB/n02391049_2231.jpg
# horse2zebra/trainB/n02391049_4569.jpg
# horse2zebra/trainB/n02391049_8844.jpg
# horse2zebra/trainB/n02391049_3122.jpg
# horse2zebra/trainB/n02391049_9951.jpg
# horse2zebra/trainB/n02391049_5595.jpg
# horse2zebra/trainB/n02391049_3023.jpg
# horse2zebra/trainB/n02391049_789.jpg
# horse2zebra/trainB/n02391049_314.jpg
# horse2zebra/trainB/n02391049_9555.jpg
# horse2zebra/trainB/n02391049_152.jpg
# horse2zebra/trainB/n02391049_35.jpg
# horse2zebra/trainB/n02391049_7494.jpg
# horse2zebra/trainB/n02391049_9357.jpg
# horse2zebra/trainB/n02391049_1124.jpg
# horse2zebra/trainB/n02391049_9519.jpg
# horse2zebra/trainB/n02391049_116.jpg
# horse2zebra/trainB/n02391049_2886.jpg
# horse2zebra/trainB/n02391049_3221.jpg
# horse2zebra/trainB/n02391049_2967.jpg
# horse2zebra/trainB/n02391049_71.jpg
# horse2zebra/trainB/n02391049_2266.jpg
# horse2zebra/trainB/n02391049_3319.jpg
# horse2zebra/trainB/n02391049_6622.jpg
# horse2zebra/trainB/n02391049_3238.jpg
# horse2zebra/trainB/n02391049_286.jpg
# horse2zebra/trainB/n02391049_8008.jpg
# horse2zebra/trainB/n02391049_925.jpg
# horse2zebra/trainB/n02391049_2824.jpg
# horse2zebra/trainB/n02391049_4525.jpg
# horse2zebra/trainB/n02391049_2743.jpg
# horse2zebra/trainB/n02391049_1852.jpg
# horse2zebra/trainB/n02391049_682.jpg
# horse2zebra/trainB/n02391049_2905.jpg
# horse2zebra/trainB/n02391049_2464.jpg
# horse2zebra/trainB/n02391049_565.jpg
# horse2zebra/trainB/n02391049_3517.jpg
# horse2zebra/trainB/n02391049_2383.jpg
# horse2zebra/trainB/n02391049_4165.jpg
# horse2zebra/trainB/n02391049_808.jpg
# horse2zebra/trainB/n02391049_3436.jpg
# horse2zebra/trainB/n02391049_10681.jpg
# horse2zebra/trainB/n02391049_646.jpg
# horse2zebra/trainB/n02391049_9331.jpg
# horse2zebra/trainB/n02391049_5371.jpg
# horse2zebra/trainB/n02391049_169.jpg
# horse2zebra/trainB/n02391049_9016.jpg
# horse2zebra/trainB/n02391049_2941.jpg
# horse2zebra/trainB/n02391049_1555.jpg
# horse2zebra/trainB/n02391049_2446.jpg
# horse2zebra/trainB/n02391049_9151.jpg
# horse2zebra/trainB/n02391049_10825.jpg
# horse2zebra/trainB/n02391049_628.jpg
# horse2zebra/trainB/n02391049_10429.jpg
# horse2zebra/trainB/n02391049_3733.jpg
# horse2zebra/trainB/n02391049_2842.jpg
# horse2zebra/trainB/n02391049_943.jpg
# horse2zebra/trainB/n02391049_6163.jpg
# horse2zebra/trainB/n02391049_1159.jpg
# horse2zebra/trainB/n02391049_745.jpg
# horse2zebra/trainB/n02391049_2644.jpg
# horse2zebra/trainB/n02391049_6208.jpg
# horse2zebra/trainB/n02391049_2806.jpg
# horse2zebra/trainB/n02391049_907.jpg
# horse2zebra/trainB/n02391049_5236.jpg
# horse2zebra/trainB/n02391049_826.jpg
# horse2zebra/trainB/n02391049_7018.jpg
# horse2zebra/trainB/n02391049_3292.jpg
# horse2zebra/trainB/n02391049_5551.jpg
# horse2zebra/trainB/n02391049_268.jpg
# horse2zebra/trainB/n02391049_3139.jpg
# horse2zebra/trainB/n02391049_4903.jpg
# horse2zebra/trainB/n02391049_1195.jpg
# horse2zebra/trainB/n02391049_8699.jpg
# horse2zebra/trainB/n02391049_3328.jpg
# horse2zebra/trainB/n02391049_2275.jpg
# horse2zebra/trainB/n02391049_538.jpg
# horse2zebra/trainB/n02391049_2437.jpg
# horse2zebra/trainB/n02391049_6631.jpg
# horse2zebra/trainB/n02391049_3085.jpg
# horse2zebra/trainB/n02391049_2356.jpg
# horse2zebra/trainB/n02391049_1465.jpg
# horse2zebra/trainB/n02391049_295.jpg
# horse2zebra/trainB/n02391049_9698.jpg
# horse2zebra/trainB/n02391049_3247.jpg
# horse2zebra/trainB/n02391049_2518.jpg
# horse2zebra/trainB/n02391049_2671.jpg
# horse2zebra/trainB/n02391049_934.jpg
# horse2zebra/trainB/n02391049_5344.jpg
# horse2zebra/trainB/n02391049_2752.jpg
# horse2zebra/trainB/n02391049_3805.jpg
# horse2zebra/trainB/n02391049_10339.jpg
# horse2zebra/trainB/n02391049_9421.jpg
# horse2zebra/trainB/n02391049_9977.jpg
# horse2zebra/trainB/n02391049_574.jpg
# horse2zebra/trainB/n02391049_817.jpg
# horse2zebra/trainB/n02391049_1267.jpg
# horse2zebra/trainB/n02391049_7324.jpg
# horse2zebra/trainB/n02391049_178.jpg
# horse2zebra/trainB/n02391049_2239.jpg
# horse2zebra/trainB/n02391049_718.jpg
# horse2zebra/trainB/n02391049_2293.jpg
# horse2zebra/trainB/n02391049_556.jpg
# horse2zebra/trainB/n02391049_10591.jpg
# horse2zebra/trainB/n02391049_475.jpg
# horse2zebra/trainB/n02391049_5209.jpg
# horse2zebra/trainB/n02391049_3265.jpg
# horse2zebra/trainB/n02391049_7306.jpg
# horse2zebra/trainB/n02391049_1087.jpg
# horse2zebra/trainB/n02391049_916.jpg
# horse2zebra/trainB/n02391049_2491.jpg
# horse2zebra/trainB/n02391049_835.jpg
# horse2zebra/trainB/n02391049_10159.jpg
# horse2zebra/trainB/n02391049_3229.jpg
# horse2zebra/trainB/n02391049_10636.jpg
# horse2zebra/trainB/n02391049_79.jpg
# horse2zebra/trainB/n02391049_3148.jpg
# horse2zebra/trainB/n02391049_7261.jpg
# horse2zebra/trainB/n02391049_358.jpg
# horse2zebra/trainB/n02391049_7979.jpg
# horse2zebra/trainB/n02391049_444.jpg
# horse2zebra/trainB/n02391049_3072.jpg
# horse2zebra/trainB/n02391049_2899.jpg
# horse2zebra/trainB/n02391049_2181.jpg
# horse2zebra/trainB/n02391049_2424.jpg
# horse2zebra/trainB/n02391049_3153.jpg
# horse2zebra/trainB/n02391049_363.jpg
# horse2zebra/trainB/n02391049_2901.jpg
# horse2zebra/trainB/n02391049_1056.jpg
# horse2zebra/trainB/n02391049_921.jpg
# horse2zebra/trainB/n02391049_4161.jpg
# horse2zebra/trainB/n02391049_4879.jpg
# horse2zebra/trainB/n02391049_642.jpg
# horse2zebra/trainB/n02391049_2541.jpg
# horse2zebra/trainB/n02391049_1731.jpg
# horse2zebra/trainB/n02391049_3513.jpg
# horse2zebra/trainB/n02391049_10209.jpg
# horse2zebra/trainB/n02391049_9964.jpg
# horse2zebra/trainB/n02391049_10047.jpg
# horse2zebra/trainB/n02391049_165.jpg
# horse2zebra/trainB/n02391049_246.jpg
# horse2zebra/trainB/n02391049_9487.jpg
# horse2zebra/trainB/n02391049_2361.jpg
# horse2zebra/trainB/n02391049_2523.jpg
# horse2zebra/trainB/n02391049_543.jpg
# horse2zebra/trainB/n02391049_3333.jpg
# horse2zebra/trainB/n02391049_1551.jpg
# horse2zebra/trainB/n02391049_5115.jpg
# horse2zebra/trainB/n02391049_147.jpg
# horse2zebra/trainB/n02391049_8659.jpg
# horse2zebra/trainB/n02391049_228.jpg
# horse2zebra/trainB/n02391049_1236.jpg
# horse2zebra/trainB/n02391049_3018.jpg
# horse2zebra/trainB/n02391049_5788.jpg
# horse2zebra/trainB/n02391049_1038.jpg
# horse2zebra/trainB/n02391049_8857.jpg
# horse2zebra/trainB/n02391049_3135.jpg
# horse2zebra/trainB/n02391049_1191.jpg
# horse2zebra/trainB/n02391049_8301.jpg
# horse2zebra/trainB/n02391049_345.jpg
# horse2zebra/trainB/n02391049_1434.jpg
# horse2zebra/trainB/n02391049_2163.jpg
# horse2zebra/trainB/n02391049_3054.jpg
# horse2zebra/trainB/n02391049_10461.jpg
# horse2zebra/trainB/n02391049_3081.jpg
# horse2zebra/trainB/n02391049_3162.jpg
# horse2zebra/trainB/n02391049_2989.jpg
# horse2zebra/trainB/n02391049_3324.jpg
# horse2zebra/trainB/n02391049_8488.jpg
# horse2zebra/trainB/n02391049_7678.jpg
# horse2zebra/trainB/n02391049_4969.jpg
# horse2zebra/trainB/n02391049_4413.jpg
# horse2zebra/trainB/n02391049_2631.jpg
# horse2zebra/trainB/n02391049_11181.jpg
# horse2zebra/trainB/n02391049_10452.jpg
# horse2zebra/trainB/n02391049_471.jpg
# horse2zebra/trainB/n02391049_633.jpg
# horse2zebra/trainB/n02391049_3261.jpg
# horse2zebra/trainB/n02391049_6015.jpg
# horse2zebra/trainB/n02391049_2451.jpg
# horse2zebra/trainB/n02391049_3342.jpg
# horse2zebra/trainB/n02391049_39.jpg
# horse2zebra/trainB/n02391049_2217.jpg
# horse2zebra/trainB/n02391049_1164.jpg
# horse2zebra/trainB/n02391049_2136.jpg
# horse2zebra/trainB/n02391049_9478.jpg
# horse2zebra/trainB/n02391049_2811.jpg
# horse2zebra/trainB/n02391049_9919.jpg
# horse2zebra/trainB/n02391049_2091.jpg
# horse2zebra/trainB/n02391049_192.jpg
# horse2zebra/trainB/n02391049_1524.jpg
# horse2zebra/trainB/n02391049_354.jpg
# horse2zebra/trainB/n02391049_3306.jpg
# horse2zebra/trainB/n02391049_10649.jpg
# horse2zebra/trainB/n02391049_4682.jpg
# horse2zebra/trainB/n02391049_9137.jpg
# horse2zebra/trainB/n02391049_3872.jpg
# horse2zebra/trainB/n02391049_686.jpg
# horse2zebra/trainB/n02391049_2585.jpg
# horse2zebra/trainB/n02391049_9533.jpg
# horse2zebra/trainB/n02391049_2747.jpg
# horse2zebra/trainB/n02391049_3001.jpg
# horse2zebra/trainB/n02391049_4448.jpg
# horse2zebra/trainB/n02391049_1937.jpg
# horse2zebra/trainB/n02391049_929.jpg
# horse2zebra/trainB/n02391049_7832.jpg
# horse2zebra/trainB/n02391049_2549.jpg
# horse2zebra/trainB/n02391049_8444.jpg
# horse2zebra/trainB/n02391049_9416.jpg
# horse2zebra/trainB/n02391049_5618.jpg
# horse2zebra/trainB/n02391049_7319.jpg
# horse2zebra/trainB/n02391049_3755.jpg
# horse2zebra/trainB/n02391049_1973.jpg
# horse2zebra/trainB/n02391049_3917.jpg
# horse2zebra/trainB/n02391049_9317.jpg
# horse2zebra/trainB/n02391049_3098.jpg
# horse2zebra/trainB/n02391049_2927.jpg
# horse2zebra/trainB/n02391049_5276.jpg
# horse2zebra/trainB/n02391049_866.jpg
# horse2zebra/trainB/n02391049_2684.jpg
# horse2zebra/trainB/n02391049_2567.jpg
# horse2zebra/trainB/n02391049_3296.jpg
# horse2zebra/trainB/n02391049_2729.jpg
# horse2zebra/trainB/n02391049_2648.jpg
# horse2zebra/trainB/n02391049_2486.jpg
# horse2zebra/trainB/n02391049_587.jpg
# horse2zebra/trainB/n02391049_2963.jpg
# horse2zebra/trainB/n02391049_4745.jpg
# horse2zebra/trainB/n02391049_1199.jpg
# horse2zebra/trainB/n02391049_7418.jpg
# horse2zebra/trainB/n02391049_9911.jpg
# horse2zebra/trainB/n02391049_983.jpg
# horse2zebra/trainB/n02391049_7364.jpg
# horse2zebra/trainB/n02391049_10739.jpg
# horse2zebra/trainB/n02391049_695.jpg
# horse2zebra/trainB/n02391049_22.jpg
# horse2zebra/trainB/n02391049_2756.jpg
# horse2zebra/trainB/n02391049_857.jpg
# horse2zebra/trainB/n02391049_9542.jpg
# horse2zebra/trainB/n02391049_1946.jpg
# horse2zebra/trainB/n02391049_776.jpg
# horse2zebra/trainB/n02391049_2837.jpg
# horse2zebra/trainB/n02391049_659.jpg
# horse2zebra/trainB/n02391049_8291.jpg
# horse2zebra/trainB/n02391049_497.jpg
# horse2zebra/trainB/n02391049_2639.jpg
# horse2zebra/trainB/n02391049_4259.jpg
# horse2zebra/trainB/n02391049_2477.jpg
# horse2zebra/trainB/n02391049_578.jpg
# horse2zebra/trainB/n02391049_7409.jpg
# horse2zebra/trainB/n02391049_5924.jpg
# horse2zebra/trainB/n02391049_2297.jpg
# horse2zebra/trainB/n02391049_4952.jpg
# horse2zebra/trainB/n02391049_1012.jpg
# horse2zebra/trainB/n02391049_8192.jpg
# horse2zebra/trainB/n02391049_2459.jpg
# horse2zebra/trainB/n02391049_875.jpg
# horse2zebra/trainB/n02391049_8831.jpg
# horse2zebra/trainB/n02391049_2693.jpg
# horse2zebra/trainB/n02391049_4475.jpg
# horse2zebra/trainB/n02391049_956.jpg
# horse2zebra/trainB/n02391049_4.jpg
# horse2zebra/trainB/n02391049_5366.jpg
# horse2zebra/trainB/n02391049_8633.jpg
# horse2zebra/trainB/n02391049_839.jpg
# horse2zebra/trainB/n02391049_121.jpg
# horse2zebra/trainB/n02391049_9524.jpg
# horse2zebra/trainB/n02391049_1928.jpg
# horse2zebra/trainB/n02391049_2657.jpg
# horse2zebra/trainB/n02391049_9443.jpg
# horse2zebra/trainB/n02391049_2819.jpg
# horse2zebra/trainB/n02391049_202.jpg
# horse2zebra/trainB/n02391049_2495.jpg
# horse2zebra/trainB/n02391049_596.jpg
# horse2zebra/trainB/n02391049_6374.jpg
# horse2zebra/trainB/n02391049_6293.jpg
# horse2zebra/trainB/n02391049_8075.jpg
# horse2zebra/trainB/n02391049_992.jpg
# horse2zebra/trainB/n02391049_127.jpg
# horse2zebra/trainB/n02391049_10324.jpg
# horse2zebra/trainB/n02391049_1135.jpg
# horse2zebra/trainB/n02391049_1054.jpg
# horse2zebra/trainB/n02391049_1531.jpg
# horse2zebra/trainB/n02391049_2897.jpg
# horse2zebra/trainB/n02391049_3232.jpg
# horse2zebra/trainB/n02391049_2341.jpg
# horse2zebra/trainB/n02391049_163.jpg
# horse2zebra/trainB/n02391049_46.jpg
# horse2zebra/trainB/n02391049_3115.jpg
# horse2zebra/trainB/n02391049_406.jpg
# horse2zebra/trainB/n02391049_3034.jpg
# horse2zebra/trainB/n02391049_5131.jpg
# horse2zebra/trainB/n02391049_721.jpg
# horse2zebra/trainB/n02391049_2701.jpg
# horse2zebra/trainB/n02391049_10504.jpg
# horse2zebra/trainB/n02391049_10342.jpg
# horse2zebra/trainB/n02391049_8657.jpg
# horse2zebra/trainB/n02391049_1153.jpg
# horse2zebra/trainB/n02391049_7847.jpg
# horse2zebra/trainB/n02391049_226.jpg
# horse2zebra/trainB/n02391049_9629.jpg
# horse2zebra/trainB/n02391049_3016.jpg
# horse2zebra/trainB/n02391049_541.jpg
# horse2zebra/trainB/n02391049_2996.jpg
# horse2zebra/trainB/n02391049_10027.jpg
# horse2zebra/trainB/n02391049_4697.jpg
# horse2zebra/trainB/n02391049_2798.jpg
# horse2zebra/trainB/n02391049_8855.jpg
# horse2zebra/trainB/n02391049_2242.jpg
# horse2zebra/trainB/n02391049_343.jpg
# horse2zebra/trainB/n02391049_2879.jpg
# horse2zebra/trainB/n02391049_9665.jpg
# horse2zebra/trainB/n02391049_424.jpg
# horse2zebra/trainB/n02391049_7487.jpg
# horse2zebra/trainB/n02391049_6202.jpg
# horse2zebra/trainB/n02391049_10063.jpg
# horse2zebra/trainB/n02391049_6121.jpg
# horse2zebra/trainB/n02391049_109.jpg
# horse2zebra/trainB/n02391049_19.jpg
# horse2zebra/trainB/n02391049_6866.jpg
# horse2zebra/trainB/n02391049_7919.jpg
# horse2zebra/trainB/n02391049_9377.jpg
# horse2zebra/trainB/n02391049_1063.jpg
# horse2zebra/trainB/n02391049_217.jpg
# horse2zebra/trainB/n02391049_2116.jpg
# horse2zebra/trainB/n02391049_6947.jpg
# horse2zebra/trainB/n02391049_3878.jpg
# horse2zebra/trainB/n02391049_2789.jpg
# horse2zebra/trainB/n02391049_9656.jpg
# horse2zebra/trainB/n02391049_415.jpg
# horse2zebra/trainB/n02391049_3043.jpg
# horse2zebra/trainB/n02391049_9494.jpg
# horse2zebra/trainB/n02391049_8288.jpg
# horse2zebra/trainB/n02391049_37.jpg
# horse2zebra/trainB/n02391049_154.jpg
# horse2zebra/trainB/n02391049_9719.jpg
# horse2zebra/trainB/n02391049_316.jpg
# horse2zebra/trainB/n02391049_10432.jpg
# horse2zebra/trainB/n02391049_712.jpg
# horse2zebra/trainB/n02391049_514.jpg
# horse2zebra/trainB/n02391049_9593.jpg
# horse2zebra/trainB/n02391049_2251.jpg
# horse2zebra/trainB/n02391049_5005.jpg
# horse2zebra/trainB/n02391049_2888.jpg
# horse2zebra/trainB/n02391049_1441.jpg
# horse2zebra/trainB/n02391049_3779.jpg
# horse2zebra/trainB/n02391049_8387.jpg
# horse2zebra/trainB/n02391049_1126.jpg
# horse2zebra/trainB/n02391049_2017.jpg
# horse2zebra/trainB/n02391049_118.jpg
# horse2zebra/trainB/n02391049_2907.jpg
# horse2zebra/trainB/n02391049_7911.jpg
# horse2zebra/trainB/n02391049_3636.jpg
# horse2zebra/trainB/n02391049_7038.jpg
# horse2zebra/trainB/n02391049_11.jpg
# horse2zebra/trainB/n02391049_927.jpg
# horse2zebra/trainB/n02391049_2826.jpg
# horse2zebra/trainB/n02391049_7434.jpg
# horse2zebra/trainB/n02391049_1296.jpg
# horse2zebra/trainB/n02391049_9135.jpg
# horse2zebra/trainB/n02391049_2187.jpg
# horse2zebra/trainB/n02391049_7236.jpg
# horse2zebra/trainB/n02391049_7074.jpg
# horse2zebra/trainB/n02391049_2781.jpg
# horse2zebra/trainB/n02391049_4644.jpg
# horse2zebra/trainB/n02391049_2628.jpg
# horse2zebra/trainB/n02391049_2466.jpg
# horse2zebra/trainB/n02391049_2709.jpg
# horse2zebra/trainB/n02391049_4329.jpg
# horse2zebra/trainB/n02391049_3276.jpg
# horse2zebra/trainB/n02391049_1818.jpg
# horse2zebra/trainB/n02391049_3654.jpg
# horse2zebra/trainB/n02391049_8028.jpg
# horse2zebra/trainB/n02391049_2844.jpg
# horse2zebra/trainB/n02391049_10269.jpg
# horse2zebra/trainB/n02391049_3339.jpg
# horse2zebra/trainB/n02391049_2286.jpg
# horse2zebra/trainB/n02391049_6561.jpg
# horse2zebra/trainB/n02391049_2448.jpg
# horse2zebra/trainB/n02391049_3177.jpg
# horse2zebra/trainB/n02391049_2367.jpg
# horse2zebra/trainB/n02391049_468.jpg
# horse2zebra/trainB/n02391049_3096.jpg
# horse2zebra/trainB/n02391049_6804.jpg
# horse2zebra/trainB/n02391049_7416.jpg
# horse2zebra/trainB/n02391049_4824.jpg
# horse2zebra/trainB/n02391049_10467.jpg
# horse2zebra/trainB/n02391049_3771.jpg
# horse2zebra/trainB/n02391049_6444.jpg
# horse2zebra/trainB/n02391049_909.jpg
# horse2zebra/trainB/n02391049_7812.jpg
# horse2zebra/trainB/n02391049_4185.jpg
# horse2zebra/trainB/n02391049_3294.jpg
# horse2zebra/trainB/n02391049_1836.jpg
# horse2zebra/trainB/n02391049_2916.jpg
# horse2zebra/trainB/n02391049_2673.jpg
# horse2zebra/trainB/n02391049_936.jpg
# horse2zebra/trainB/n02391049_8334.jpg
# horse2zebra/trainB/n02391049_2439.jpg
# horse2zebra/trainB/n02391049_5661.jpg
# horse2zebra/trainB/n02391049_4932.jpg
# horse2zebra/trainB/n02391049_459.jpg
# horse2zebra/trainB/n02391049_3087.jpg
# horse2zebra/trainB/n02391049_3249.jpg
# horse2zebra/trainB/n02391049_6471.jpg
# horse2zebra/trainB/n02391049_3681.jpg
# horse2zebra/trainB/n02391049_4734.jpg
# horse2zebra/trainB/n02391049_1188.jpg
# horse2zebra/trainB/n02391049_9027.jpg
# horse2zebra/trainB/n02391049_7407.jpg
# horse2zebra/trainB/n02391049_2871.jpg
# horse2zebra/trainB/n02391049_1908.jpg
# horse2zebra/trainB/n02391049_2637.jpg
# horse2zebra/trainB/n02391049_738.jpg
# horse2zebra/trainB/n02391049_9979.jpg
# horse2zebra/trainB/n02391049_101.jpg
# horse2zebra/trainB/n02391049_2718.jpg
# horse2zebra/trainB/n02391049_7722.jpg
# horse2zebra/trainB/n02391049_4176.jpg
# horse2zebra/trainB/n02391049_1827.jpg
# horse2zebra/trainB/n02391049_873.jpg
# horse2zebra/trainB/n02391049_6336.jpg
# horse2zebra/trainB/n02391049_2691.jpg
# horse2zebra/trainB/n02391049_2.jpg
# horse2zebra/trainB/n02391049_3582.jpg
# horse2zebra/trainB/n02391049_10278.jpg
# horse2zebra/trainB/n02391049_2853.jpg
# horse2zebra/trainB/n02391049_954.jpg
# horse2zebra/trainB/n02391049_2295.jpg
# horse2zebra/trainB/n02391049_396.jpg
# horse2zebra/trainB/n02391049_3348.jpg
# horse2zebra/trainB/n02391049_4077.jpg
# horse2zebra/trainB/n02391049_2457.jpg
# horse2zebra/trainB/n02391049_10917.jpg
# horse2zebra/trainB/n02391049_3267.jpg
# horse2zebra/trainB/n02391049_639.jpg
# horse2zebra/trainB/n02391049_7263.jpg
# horse2zebra/trainB/n02391049_3861.jpg
# horse2zebra/trainB/n02391049_4914.jpg
# horse2zebra/trainB/n02391049_7344.jpg
# horse2zebra/trainB/n02391049_3069.jpg
# horse2zebra/trainB/n02391049_5724.jpg
# horse2zebra/trainB/n02391049_279.jpg
# horse2zebra/trainB/n02391049_9441.jpg
# horse2zebra/trainB/n02391049_918.jpg
# horse2zebra/trainB/n02391049_2817.jpg
# horse2zebra/trainB/n02391049_3465.jpg
# horse2zebra/trainB/n02391049_675.jpg
# horse2zebra/trainB/n02391049_5889.jpg
# horse2zebra/trainB/n02391049_7115.jpg
# horse2zebra/trainB/n02391049_5333.jpg
# horse2zebra/trainB/n02391049_2741.jpg
# horse2zebra/trainB/n02391049_2183.jpg
# horse2zebra/trainB/n02391049_2507.jpg
# horse2zebra/trainB/n02391049_608.jpg
# horse2zebra/trainB/n02391049_3236.jpg
# horse2zebra/trainB/n02391049_527.jpg
# horse2zebra/trainB/n02391049_1535.jpg
# horse2zebra/trainB/n02391049_3317.jpg
# horse2zebra/trainB/n02391049_8321.jpg
# horse2zebra/trainB/n02391049_1256.jpg
# horse2zebra/trainB/n02391049_3038.jpg
# horse2zebra/trainB/n02391049_7151.jpg
# horse2zebra/trainB/n02391049_248.jpg
# horse2zebra/trainB/n02391049_167.jpg
# horse2zebra/trainB/n02391049_3119.jpg
# horse2zebra/trainB/n02391049_6503.jpg
# horse2zebra/trainB/n02391049_2228.jpg
# horse2zebra/trainB/n02391049_329.jpg
# horse2zebra/trainB/n02391049_1175.jpg
# horse2zebra/trainB/n02391049_5216.jpg
# horse2zebra/trainB/n02391049_1652.jpg
# horse2zebra/trainB/n02391049_2381.jpg
# horse2zebra/trainB/n02391049_8994.jpg
# horse2zebra/trainB/n02391049_644.jpg
# horse2zebra/trainB/n02391049_6026.jpg
# horse2zebra/trainB/n02391049_3191.jpg
# horse2zebra/trainB/n02391049_725.jpg
# horse2zebra/trainB/n02391049_10427.jpg
# horse2zebra/trainB/n02391049_1076.jpg
# horse2zebra/trainB/n02391049_2048.jpg
# horse2zebra/trainB/n02391049_2921.jpg
# horse2zebra/trainB/n02391049_3092.jpg
# horse2zebra/trainB/n02391049_2363.jpg
# horse2zebra/trainB/n02391049_626.jpg
# horse2zebra/trainB/n02391049_3173.jpg
# horse2zebra/trainB/n02391049_383.jpg
# horse2zebra/trainB/n02391049_707.jpg
# horse2zebra/trainB/n02391049_2606.jpg
# horse2zebra/trainB/n02391049_9113.jpg
# horse2zebra/trainB/n02391049_428.jpg
# horse2zebra/trainB/n02391049_2165.jpg
# horse2zebra/trainB/n02391049_5711.jpg
# horse2zebra/trainB/n02391049_1436.jpg
# horse2zebra/trainB/n02391049_1355.jpg
# horse2zebra/trainB/n02391049_4901.jpg
# horse2zebra/trainB/n02391049_2408.jpg
# horse2zebra/trainB/n02391049_3137.jpg
# horse2zebra/trainB/n02391049_8859.jpg
# horse2zebra/trainB/n02391049_4028.jpg
# horse2zebra/trainB/n02391049_824.jpg
# horse2zebra/trainB/n02391049_2723.jpg
# horse2zebra/trainB/n02391049_1751.jpg
# horse2zebra/trainB/n02391049_743.jpg
# horse2zebra/trainB/n02391049_2642.jpg
# horse2zebra/trainB/n02391049_3371.jpg
# horse2zebra/trainB/n02391049_8015.jpg
# horse2zebra/trainB/n02391049_1067.jpg
# horse2zebra/trainB/n02391049_932.jpg
# horse2zebra/trainB/n02391049_2831.jpg
# horse2zebra/trainB/n02391049_851.jpg
# horse2zebra/trainB/n02391049_10175.jpg
# horse2zebra/trainB/n02391049_7599.jpg
# horse2zebra/trainB/n02391049_1148.jpg
# horse2zebra/trainB/n02391049_7205.jpg
# horse2zebra/trainB/n02391049_536.jpg
# horse2zebra/trainB/n02391049_3326.jpg
# horse2zebra/trainB/n02391049_9777.jpg
# horse2zebra/trainB/n02391049_2273.jpg
# horse2zebra/trainB/n02391049_419.jpg
# horse2zebra/trainB/n02391049_10454.jpg
# horse2zebra/trainB/n02391049_6987.jpg
# horse2zebra/trainB/n02391049_3209.jpg
# horse2zebra/trainB/n02391049_3128.jpg
# horse2zebra/trainB/n02391049_176.jpg
# horse2zebra/trainB/n02391049_1184.jpg
# horse2zebra/trainB/n02391049_6512.jpg
# horse2zebra/trainB/n02391049_2714.jpg
# horse2zebra/trainB/n02391049_3443.jpg
# horse2zebra/trainB/n02391049_1742.jpg
# horse2zebra/trainB/n02391049_734.jpg
# horse2zebra/trainB/n02391049_2633.jpg
# horse2zebra/trainB/n02391049_6413.jpg
# horse2zebra/trainB/n02391049_2057.jpg
# horse2zebra/trainB/n02391049_7779.jpg
# horse2zebra/trainB/n02391049_2372.jpg
# horse2zebra/trainB/n02391049_635.jpg
# horse2zebra/trainB/n02391049_2534.jpg
# horse2zebra/trainB/n02391049_554.jpg
# horse2zebra/trainB/n02391049_392.jpg
# horse2zebra/trainB/n02391049_437.jpg
# horse2zebra/trainB/n02391049_9122.jpg
# horse2zebra/trainB/n02391049_275.jpg
# horse2zebra/trainB/n02391049_77.jpg
# horse2zebra/trainB/n02391049_356.jpg
# horse2zebra/trainB/n02391049_1526.jpg
# horse2zebra/trainB/n02391049_2732.jpg
# horse2zebra/trainB/n02391049_671.jpg
# horse2zebra/trainB/n02391049_3623.jpg
# horse2zebra/trainB/n02391049_6053.jpg
# horse2zebra/trainB/n02391049_2813.jpg
# horse2zebra/trainB/n02391049_752.jpg
# horse2zebra/trainB/n02391049_2651.jpg
# horse2zebra/trainB/n02391049_10966.jpg
# horse2zebra/trainB/n02391049_3397.jpg
# horse2zebra/trainB/n02391049_2749.jpg
# horse2zebra/trainB/n02391049_15.jpg
# horse2zebra/trainB/n02391049_9058.jpg
# horse2zebra/trainB/n02391049_6385.jpg
# horse2zebra/trainB/n02391049_1894.jpg
# horse2zebra/trainB/n02391049_4729.jpg
# horse2zebra/trainB/n02391049_2785.jpg
# horse2zebra/trainB/n02391049_886.jpg
# horse2zebra/trainB/n02391049_1104.jpg
# horse2zebra/trainB/n02391049_10131.jpg
# horse2zebra/trainB/n02391049_6664.jpg
# horse2zebra/trainB/n02391049_3199.jpg
# horse2zebra/trainB/n02391049_949.jpg
# horse2zebra/trainB/n02391049_2848.jpg
# horse2zebra/trainB/n02391049_787.jpg
# horse2zebra/trainB/n02391049_2211.jpg
# horse2zebra/trainB/n02391049_33.jpg
# horse2zebra/trainB/n02391049_2767.jpg
# horse2zebra/trainB/n02391049_8266.jpg
# horse2zebra/trainB/n02391049_5755.jpg
# horse2zebra/trainB/n02391049_8347.jpg
# horse2zebra/trainB/n02391049_6565.jpg
# horse2zebra/trainB/n02391049_3937.jpg
# horse2zebra/trainB/n02391049_985.jpg
# horse2zebra/trainB/n02391049_4747.jpg
# horse2zebra/trainB/n02391049_7258.jpg
# horse2zebra/trainB/n02391049_4909.jpg
# horse2zebra/trainB/n02391049_7096.jpg
# horse2zebra/trainB/n02391049_5638.jpg
# horse2zebra/trainB/n02391049_8149.jpg
# horse2zebra/trainB/n02391049_5791.jpg
# horse2zebra/trainB/n02391049_9193.jpg
# horse2zebra/trainB/n02391049_4189.jpg
# horse2zebra/trainB/n02391049_10948.jpg
# horse2zebra/trainB/n02391049_589.jpg
# horse2zebra/trainB/n02391049_9625.jpg
# horse2zebra/trainB/n02391049_2596.jpg
# horse2zebra/trainB/n02391049_2758.jpg
# horse2zebra/trainB/n02391049_141.jpg
# horse2zebra/trainB/n02391049_6475.jpg
# horse2zebra/trainB/n02391049_4693.jpg
# horse2zebra/trainB/n02391049_5908.jpg
# horse2zebra/trainB/n02391049_2875.jpg
# horse2zebra/trainB/n02391049_976.jpg
# horse2zebra/trainB/n02391049_8059.jpg
# horse2zebra/trainB/n02391049_501.jpg
# horse2zebra/trainB/n02391049_4576.jpg
# horse2zebra/trainB/n02391049_2794.jpg
# horse2zebra/trainB/n02391049_5782.jpg
# horse2zebra/trainB/n02391049_3289.jpg
# horse2zebra/trainB/n02391049_1113.jpg
# horse2zebra/trainB/n02391049_499.jpg
# horse2zebra/trainB/n02391049_9427.jpg
# horse2zebra/trainB/n02391049_7645.jpg
# horse2zebra/trainB/n02391049_2857.jpg
# horse2zebra/trainB/n02391049_6097.jpg
# horse2zebra/trainB/n02391049_796.jpg
# horse2zebra/trainB/n02391049_2776.jpg
# horse2zebra/trainB/n02391049_6655.jpg
# horse2zebra/trainB/n02391049_4873.jpg
# horse2zebra/trainB/n02391049_10122.jpg
# horse2zebra/trainB/n02391049_10597.jpg
# horse2zebra/trainB/n02391049_2974.jpg
# horse2zebra/trainB/n02391049_8158.jpg
# horse2zebra/trainB/n02391049_9922.jpg
# horse2zebra/trainB/n02391049_1131.jpg
# horse2zebra/trainB/n02391049_2659.jpg
# horse2zebra/trainB/n02391049_2223.jpg
# horse2zebra/trainB/n02391049_45.jpg
# horse2zebra/trainB/n02391049_2061.jpg
# horse2zebra/trainB/n02391049_3114.jpg
# horse2zebra/trainB/n02391049_2698.jpg
# horse2zebra/trainB/n02391049_2304.jpg
# horse2zebra/trainB/n02391049_8593.jpg
# horse2zebra/trainB/n02391049_3868.jpg
# horse2zebra/trainB/n02391049_9844.jpg
# horse2zebra/trainB/n02391049_3949.jpg
# horse2zebra/trainB/n02391049_603.jpg
# horse2zebra/trainB/n02391049_1053.jpg
# horse2zebra/trainB/n02391049_6775.jpg
# horse2zebra/trainB/n02391049_6856.jpg
# horse2zebra/trainB/n02391049_10701.jpg
# horse2zebra/trainB/n02391049_2959.jpg
# horse2zebra/trainB/n02391049_63.jpg
# horse2zebra/trainB/n02391049_9583.jpg
# horse2zebra/trainB/n02391049_6991.jpg
# horse2zebra/trainB/n02391049_2322.jpg
# horse2zebra/trainB/n02391049_261.jpg
# horse2zebra/trainB/n02391049_7648.jpg
# horse2zebra/trainB/n02391049_6919.jpg
# horse2zebra/trainB/n02391049_8539.jpg
# horse2zebra/trainB/n02391049_6757.jpg
# horse2zebra/trainB/n02391049_108.jpg
# horse2zebra/trainB/n02391049_5947.jpg
# horse2zebra/trainB/n02391049_7567.jpg
# horse2zebra/trainB/n02391049_2995.jpg
# horse2zebra/trainB/n02391049_621.jpg
# horse2zebra/trainB/n02391049_225.jpg
# horse2zebra/trainB/n02391049_1789.jpg
# horse2zebra/trainB/n02391049_1314.jpg
# horse2zebra/trainB/n02391049_2043.jpg
# horse2zebra/trainB/n02391049_306.jpg
# horse2zebra/trainB/n02391049_7927.jpg
# horse2zebra/trainB/n02391049_2232.jpg
# horse2zebra/trainB/n02391049_333.jpg
# horse2zebra/trainB/n02391049_2788.jpg
# horse2zebra/trainB/n02391049_171.jpg
# horse2zebra/trainB/n02391049_8764.jpg
# horse2zebra/trainB/n02391049_1026.jpg
# horse2zebra/trainB/n02391049_5695.jpg
# horse2zebra/trainB/n02391049_7396.jpg
# horse2zebra/trainB/n02391049_10134.jpg
# horse2zebra/trainB/n02391049_3402.jpg
# horse2zebra/trainB/n02391049_2511.jpg
# horse2zebra/trainB/n02391049_3958.jpg
# horse2zebra/trainB/n02391049_6469.jpg
# horse2zebra/trainB/n02391049_1062.jpg
# horse2zebra/trainB/n02391049_2034.jpg
# horse2zebra/trainB/n02391049_18.jpg
# horse2zebra/trainB/n02391049_7972.jpg
# horse2zebra/trainB/n02391049_351.jpg
# horse2zebra/trainB/n02391049_3303.jpg
# horse2zebra/trainB/n02391049_8782.jpg
# horse2zebra/trainB/n02391049_3778.jpg
# horse2zebra/trainB/n02391049_5875.jpg
# horse2zebra/trainB/n02391049_1125.jpg
# horse2zebra/trainB/n02391049_5121.jpg
# horse2zebra/trainB/n02391049_711.jpg
# horse2zebra/trainB/n02391049_6012.jpg
# horse2zebra/trainB/n02391049_7378.jpg
# horse2zebra/trainB/n02391049_6487.jpg
# horse2zebra/trainB/n02391049_3024.jpg
# horse2zebra/trainB/n02391049_1404.jpg
# horse2zebra/trainB/n02391049_234.jpg
# horse2zebra/trainB/n02391049_2133.jpg
# horse2zebra/trainB/n02391049_9556.jpg
# horse2zebra/trainB/n02391049_3105.jpg
# horse2zebra/trainB/n02391049_36.jpg
# horse2zebra/trainB/n02391049_2214.jpg
# horse2zebra/trainB/n02391049_5291.jpg
# horse2zebra/trainB/n02391049_1178.jpg
# horse2zebra/trainB/n02391049_1097.jpg
# horse2zebra/trainB/n02391049_4805.jpg
# horse2zebra/trainB/n02391049_566.jpg
# horse2zebra/trainB/n02391049_2465.jpg
# horse2zebra/trainB/n02391049_3518.jpg
# horse2zebra/trainB/n02391049_6902.jpg
# horse2zebra/trainB/n02391049_2627.jpg
# horse2zebra/trainB/n02391049_1817.jpg
# horse2zebra/trainB/n02391049_10682.jpg
# horse2zebra/trainB/n02391049_809.jpg
# horse2zebra/trainB/n02391049_3158.jpg
# horse2zebra/trainB/n02391049_4922.jpg
# horse2zebra/trainB/n02391049_368.jpg
# horse2zebra/trainB/n02391049_3239.jpg
# horse2zebra/trainB/n02391049_1295.jpg
# horse2zebra/trainB/n02391049_2825.jpg
# horse2zebra/trainB/n02391049_926.jpg
# horse2zebra/trainB/n02391049_2663.jpg
# horse2zebra/trainB/n02391049_764.jpg
# horse2zebra/trainB/n02391049_6227.jpg
# horse2zebra/trainB/n02391049_4445.jpg
# horse2zebra/trainB/n02391049_2906.jpg
# horse2zebra/trainB/n02391049_5093.jpg
# horse2zebra/trainB/n02391049_5633.jpg
# horse2zebra/trainB/n02391049_6524.jpg
# horse2zebra/trainB/n02391049_5714.jpg
# horse2zebra/trainB/n02391049_11195.jpg
# horse2zebra/trainB/n02391049_584.jpg
# horse2zebra/trainB/n02391049_9987.jpg
# horse2zebra/trainB/n02391049_3536.jpg
# horse2zebra/trainB/n02391049_2645.jpg
# horse2zebra/trainB/n02391049_3293.jpg
# horse2zebra/trainB/n02391049_2609.jpg
# horse2zebra/trainB/n02391049_2285.jpg
# horse2zebra/trainB/n02391049_629.jpg
# horse2zebra/trainB/n02391049_3257.jpg
# horse2zebra/trainB/n02391049_2366.jpg
# horse2zebra/trainB/n02391049_944.jpg
# horse2zebra/trainB/n02391049_6245.jpg
# horse2zebra/trainB/n02391049_2681.jpg
# horse2zebra/trainB/n02391049_1952.jpg
# horse2zebra/trainB/n02391049_2924.jpg
# horse2zebra/trainB/n02391049_6326.jpg
# horse2zebra/trainB/n02391049_5273.jpg
# horse2zebra/trainB/n02391049_2951.jpg
# horse2zebra/trainB/n02391049_10295.jpg
# horse2zebra/trainB/n02391049_4814.jpg
# horse2zebra/trainB/n02391049_3365.jpg
# horse2zebra/trainB/n02391049_2636.jpg
# horse2zebra/trainB/n02391049_737.jpg
# horse2zebra/trainB/n02391049_3446.jpg
# horse2zebra/trainB/n02391049_7721.jpg
# horse2zebra/trainB/n02391049_98.jpg
# horse2zebra/trainB/n02391049_377.jpg
# horse2zebra/trainB/n02391049_9062.jpg
# horse2zebra/trainB/n02391049_4058.jpg
# horse2zebra/trainB/n02391049_3248.jpg
# horse2zebra/trainB/n02391049_3086.jpg
# horse2zebra/trainB/n02391049_4292.jpg
# horse2zebra/trainB/n02391049_935.jpg
# horse2zebra/trainB/n02391049_6074.jpg
# horse2zebra/trainB/n02391049_773.jpg
# horse2zebra/trainB/n02391049_6236.jpg
# horse2zebra/trainB/n02391049_2591.jpg
# horse2zebra/trainB/n02391049_6317.jpg
# horse2zebra/trainB/n02391049_3149.jpg
# horse2zebra/trainB/n02391049_2258.jpg
# horse2zebra/trainB/n02391049_6452.jpg
# horse2zebra/trainB/n02391049_2177.jpg
# horse2zebra/trainB/n02391049_2816.jpg
# horse2zebra/trainB/n02391049_5165.jpg
# horse2zebra/trainB/n02391049_1844.jpg
# horse2zebra/trainB/n02391049_4517.jpg
# horse2zebra/trainB/n02391049_3509.jpg
# horse2zebra/trainB/n02391049_557.jpg
# horse2zebra/trainB/n02391049_395.jpg
# horse2zebra/trainB/n02391049_2294.jpg
# horse2zebra/trainB/n02391049_10754.jpg
# horse2zebra/trainB/n02391049_719.jpg
# horse2zebra/trainB/n02391049_638.jpg
# horse2zebra/trainB/n02391049_3266.jpg
# horse2zebra/trainB/n02391049_2375.jpg
# horse2zebra/trainB/n02391049_3428.jpg
# horse2zebra/trainB/n02391049_2852.jpg
# horse2zebra/trainB/n02391049_3905.jpg
# horse2zebra/trainB/n02391049_1088.jpg
# horse2zebra/trainB/n02391049_2771.jpg
# horse2zebra/trainB/n02391049_6421.jpg
# horse2zebra/trainB/n02391049_1417.jpg
# horse2zebra/trainB/n02391049_2146.jpg
# horse2zebra/trainB/n02391049_3037.jpg
# horse2zebra/trainB/n02391049_1174.jpg
# horse2zebra/trainB/n02391049_328.jpg
# horse2zebra/trainB/n02391049_7949.jpg
# horse2zebra/trainB/n02391049_166.jpg
# horse2zebra/trainB/n02391049_3271.jpg
# horse2zebra/trainB/n02391049_643.jpg
# horse2zebra/trainB/n02391049_2704.jpg
# horse2zebra/trainB/n02391049_10129.jpg
# horse2zebra/trainB/n02391049_2623.jpg
# horse2zebra/trainB/n02391049_9965.jpg
# horse2zebra/trainB/n02391049_2506.jpg
# horse2zebra/trainB/n02391049_3235.jpg
# horse2zebra/trainB/n02391049_2182.jpg
# horse2zebra/trainB/n02391049_283.jpg
# horse2zebra/trainB/n02391049_3073.jpg
# horse2zebra/trainB/n02391049_85.jpg
# horse2zebra/trainB/n02391049_3154.jpg
# horse2zebra/trainB/n02391049_7589.jpg
# horse2zebra/trainB/n02391049_3631.jpg
# horse2zebra/trainB/n02391049_10165.jpg
# horse2zebra/trainB/n02391049_841.jpg
# horse2zebra/trainB/n02391049_2821.jpg
# horse2zebra/trainB/n02391049_7886.jpg
# horse2zebra/trainB/n02391049_427.jpg
# horse2zebra/trainB/n02391049_4027.jpg
# horse2zebra/trainB/n02391049_8696.jpg
# horse2zebra/trainB/n02391049_1516.jpg
# horse2zebra/trainB/n02391049_2407.jpg
# horse2zebra/trainB/n02391049_5789.jpg
# horse2zebra/trainB/n02391049_4898.jpg
# horse2zebra/trainB/n02391049_4261.jpg
# horse2zebra/trainB/n02391049_2803.jpg
# horse2zebra/trainB/n02391049_904.jpg
# horse2zebra/trainB/n02391049_3253.jpg
# horse2zebra/trainB/n02391049_2524.jpg
# horse2zebra/trainB/n02391049_3415.jpg
# horse2zebra/trainB/n02391049_4144.jpg
# horse2zebra/trainB/n02391049_463.jpg
# horse2zebra/trainB/n02391049_3091.jpg
# horse2zebra/trainB/n02391049_2999.jpg
# horse2zebra/trainB/n02391049_2281.jpg
# horse2zebra/trainB/n02391049_544.jpg
# horse2zebra/trainB/n02391049_1156.jpg
# horse2zebra/trainB/n02391049_148.jpg
# horse2zebra/trainB/n02391049_10426.jpg
# horse2zebra/trainB/n02391049_2155.jpg
# horse2zebra/trainB/n02391049_9497.jpg
# horse2zebra/trainB/n02391049_3046.jpg
# horse2zebra/trainB/n02391049_6511.jpg
# horse2zebra/trainB/n02391049_1183.jpg
# horse2zebra/trainB/n02391049_58.jpg
# horse2zebra/trainB/n02391049_4889.jpg
# horse2zebra/trainB/n02391049_733.jpg
# horse2zebra/trainB/n02391049_2191.jpg
# horse2zebra/trainB/n02391049_2911.jpg
# horse2zebra/trainB/n02391049_10336.jpg
# horse2zebra/trainB/n02391049_1147.jpg
# horse2zebra/trainB/n02391049_1309.jpg
# horse2zebra/trainB/n02391049_5503.jpg
# horse2zebra/trainB/n02391049_274.jpg
# horse2zebra/trainB/n02391049_2416.jpg
# horse2zebra/trainB/n02391049_193.jpg
# horse2zebra/trainB/n02391049_4351.jpg
# horse2zebra/trainB/n02391049_1129.jpg
# horse2zebra/trainB/n02391049_2731.jpg
# horse2zebra/trainB/n02391049_11128.jpg
# horse2zebra/trainB/n02391049_913.jpg
# horse2zebra/trainB/n02391049_7105.jpg
# horse2zebra/trainB/n02391049_3262.jpg
# horse2zebra/trainB/n02391049_715.jpg
# horse2zebra/trainB/n02391049_2218.jpg
# horse2zebra/trainB/n02391049_9398.jpg
# horse2zebra/trainB/n02391049_8032.jpg
# horse2zebra/trainB/n02391049_3028.jpg
# horse2zebra/trainB/n02391049_10435.jpg
# horse2zebra/trainB/n02391049_3901.jpg
# horse2zebra/trainB/n02391049_6267.jpg
# horse2zebra/trainB/n02391049_966.jpg
# horse2zebra/trainB/n02391049_5295.jpg
# horse2zebra/trainB/n02391049_7077.jpg
# horse2zebra/trainB/n02391049_2784.jpg
# horse2zebra/trainB/n02391049_6186.jpg
# horse2zebra/trainB/n02391049_2946.jpg
# horse2zebra/trainB/n02391049_8445.jpg
# horse2zebra/trainB/n02391049_9336.jpg
# horse2zebra/trainB/n02391049_2469.jpg
# horse2zebra/trainB/n02391049_8526.jpg
# horse2zebra/trainB/n02391049_5853.jpg
# horse2zebra/trainB/n02391049_6582.jpg
# horse2zebra/trainB/n02391049_9417.jpg
# horse2zebra/trainB/n02391049_6465.jpg
# horse2zebra/trainB/n02391049_9219.jpg
# horse2zebra/trainB/n02391049_6546.jpg
# horse2zebra/trainB/n02391049_2982.jpg
# horse2zebra/trainB/n02391049_2748.jpg
# horse2zebra/trainB/n02391049_2586.jpg
# horse2zebra/trainB/n02391049_2111.jpg
# horse2zebra/trainB/n02391049_2829.jpg
# horse2zebra/trainB/n02391049_6942.jpg
# horse2zebra/trainB/n02391049_6609.jpg
# horse2zebra/trainB/n02391049_1992.jpg
# horse2zebra/trainB/n02391049_984.jpg
# horse2zebra/trainB/n02391049_2883.jpg
# horse2zebra/trainB/n02391049_8148.jpg
# horse2zebra/trainB/n02391049_4584.jpg
# horse2zebra/trainB/n02391049_5637.jpg
# horse2zebra/trainB/n02391049_3693.jpg
# horse2zebra/trainB/n02391049_2964.jpg
# horse2zebra/trainB/n02391049_1121.jpg
# horse2zebra/trainB/n02391049_1758.jpg
# horse2zebra/trainB/n02391049_6762.jpg
# horse2zebra/trainB/n02391049_9273.jpg
# horse2zebra/trainB/n02391049_4863.jpg
# horse2zebra/trainB/n02391049_1479.jpg
# horse2zebra/trainB/n02391049_1004.jpg
# horse2zebra/trainB/n02391049_10749.jpg
# horse2zebra/trainB/n02391049_6564.jpg
# horse2zebra/trainB/n02391049_2289.jpg
# horse2zebra/trainB/n02391049_2766.jpg
# horse2zebra/trainB/n02391049_32.jpg
# horse2zebra/trainB/n02391049_1875.jpg
# horse2zebra/trainB/n02391049_7851.jpg
# horse2zebra/trainB/n02391049_2847.jpg
# horse2zebra/trainB/n02391049_786.jpg
# horse2zebra/trainB/n02391049_5547.jpg
# horse2zebra/trainB/n02391049_9822.jpg
# horse2zebra/trainB/n02391049_2003.jpg
# horse2zebra/trainB/n02391049_8616.jpg
# horse2zebra/trainB/n02391049_5781.jpg
# horse2zebra/trainB/n02391049_1112.jpg
# horse2zebra/trainB/n02391049_7563.jpg
# horse2zebra/trainB/n02391049_2559.jpg
# horse2zebra/trainB/n02391049_6834.jpg
# horse2zebra/trainB/n02391049_2478.jpg
# horse2zebra/trainB/n02391049_8373.jpg
# horse2zebra/trainB/n02391049_10497.jpg
# horse2zebra/trainB/n02391049_9309.jpg
# horse2zebra/trainB/n02391049_4692.jpg
# horse2zebra/trainB/n02391049_2757.jpg
# horse2zebra/trainB/n02391049_23.jpg
# horse2zebra/trainB/n02391049_2201.jpg
# horse2zebra/trainB/n02391049_6159.jpg
# horse2zebra/trainB/n02391049_9705.jpg
# horse2zebra/trainB/n02391049_2838.jpg
# horse2zebra/trainB/n02391049_221.jpg
# horse2zebra/trainB/n02391049_6951.jpg
# horse2zebra/trainB/n02391049_993.jpg
# horse2zebra/trainB/n02391049_2973.jpg
# horse2zebra/trainB/n02391049_10398.jpg
# horse2zebra/trainB/n02391049_122.jpg
# horse2zebra/trainB/n02391049_2739.jpg
# horse2zebra/trainB/n02391049_7581.jpg
# horse2zebra/trainB/n02391049_5169.jpg
# horse2zebra/trainB/n02391049_1211.jpg
# horse2zebra/trainB/n02391049_2379.jpg
# horse2zebra/trainB/n02391049_6735.jpg
# horse2zebra/trainB/n02391049_10596.jpg
# horse2zebra/trainB/n02391049_41.jpg
# horse2zebra/trainB/n02391049_1884.jpg
# horse2zebra/trainB/n02391049_2856.jpg
# horse2zebra/trainB/n02391049_957.jpg
# horse2zebra/trainB/n02391049_4638.jpg
# horse2zebra/trainB/n02391049_5367.jpg
# horse2zebra/trainB/n02391049_795.jpg
# horse2zebra/trainB/n02391049_9804.jpg
# horse2zebra/trainB/n02391049_2702.jpg
# horse2zebra/trainB/n02391049_6023.jpg
# horse2zebra/trainB/n02391049_2225.jpg
# horse2zebra/trainB/n02391049_1172.jpg
# horse2zebra/trainB/n02391049_164.jpg
# horse2zebra/trainB/n02391049_2306.jpg
# horse2zebra/trainB/n02391049_407.jpg
# horse2zebra/trainB/n02391049_8201.jpg
# horse2zebra/trainB/n02391049_7668.jpg
# horse2zebra/trainB/n02391049_10244.jpg
# horse2zebra/trainB/n02391049_1532.jpg
# horse2zebra/trainB/n02391049_362.jpg
# horse2zebra/trainB/n02391049_3314.jpg
# horse2zebra/trainB/n02391049_8793.jpg
# horse2zebra/trainB/n02391049_3071.jpg
# horse2zebra/trainB/n02391049_3233.jpg
# horse2zebra/trainB/n02391049_2504.jpg
# horse2zebra/trainB/n02391049_605.jpg
# horse2zebra/trainB/n02391049_1451.jpg
# horse2zebra/trainB/n02391049_5015.jpg
# horse2zebra/trainB/n02391049_999.jpg
# horse2zebra/trainB/n02391049_10307.jpg
# horse2zebra/trainB/n02391049_6122.jpg
# horse2zebra/trainB/n02391049_1118.jpg
# horse2zebra/trainB/n02391049_4896.jpg
# horse2zebra/trainB/n02391049_344.jpg
# horse2zebra/trainB/n02391049_9747.jpg
# horse2zebra/trainB/n02391049_506.jpg
# horse2zebra/trainB/n02391049_2405.jpg
# horse2zebra/trainB/n02391049_8856.jpg
# horse2zebra/trainB/n02391049_182.jpg
# horse2zebra/trainB/n02391049_3053.jpg
# horse2zebra/trainB/n02391049_425.jpg
# horse2zebra/trainB/n02391049_6993.jpg
# horse2zebra/trainB/n02391049_4106.jpg
# horse2zebra/trainB/n02391049_8937.jpg
# horse2zebra/trainB/n02391049_2162.jpg
# horse2zebra/trainB/n02391049_308.jpg
# horse2zebra/trainB/n02391049_9387.jpg
# horse2zebra/trainB/n02391049_5985.jpg
# horse2zebra/trainB/n02391049_8102.jpg
# horse2zebra/trainB/n02391049_1316.jpg
# horse2zebra/trainB/n02391049_146.jpg
# horse2zebra/trainB/n02391049_8021.jpg
# horse2zebra/trainB/n02391049_11153.jpg
# horse2zebra/trainB/n02391049_6957.jpg
# horse2zebra/trainB/n02391049_1235.jpg
# horse2zebra/trainB/n02391049_1073.jpg
# horse2zebra/trainB/n02391049_7848.jpg
# horse2zebra/trainB/n02391049_2997.jpg
# horse2zebra/trainB/n02391049_2603.jpg
# horse2zebra/trainB/n02391049_704.jpg
# horse2zebra/trainB/n02391049_1712.jpg
# horse2zebra/trainB/n02391049_461.jpg
# horse2zebra/trainB/n02391049_9864.jpg
# horse2zebra/trainB/n02391049_3251.jpg
# horse2zebra/trainB/n02391049_812.jpg
# horse2zebra/trainB/n02391049_7398.jpg
# horse2zebra/trainB/n02391049_1028.jpg
# horse2zebra/trainB/n02391049_1181.jpg
# horse2zebra/trainB/n02391049_335.jpg
# horse2zebra/trainB/n02391049_173.jpg
# horse2zebra/trainB/n02391049_56.jpg
# horse2zebra/trainB/n02391049_3044.jpg
# horse2zebra/trainB/n02391049_254.jpg
# horse2zebra/trainB/n02391049_10613.jpg
# horse2zebra/trainB/n02391049_1145.jpg
# horse2zebra/trainB/n02391049_11063.jpg
# horse2zebra/trainB/n02391049_2036.jpg
# horse2zebra/trainB/n02391049_5501.jpg
# horse2zebra/trainB/n02391049_7839.jpg
# horse2zebra/trainB/n02391049_8568.jpg
# horse2zebra/trainB/n02391049_2117.jpg
# horse2zebra/trainB/n02391049_1064.jpg
# horse2zebra/trainB/n02391049_533.jpg
# horse2zebra/trainB/n02391049_3242.jpg
# horse2zebra/trainB/n02391049_614.jpg
# horse2zebra/trainB/n02391049_1127.jpg
# horse2zebra/trainB/n02391049_2018.jpg
# horse2zebra/trainB/n02391049_119.jpg
# horse2zebra/trainB/n02391049_1046.jpg
# horse2zebra/trainB/n02391049_4034.jpg
# horse2zebra/trainB/n02391049_1523.jpg
# horse2zebra/trainB/n02391049_353.jpg
# horse2zebra/trainB/n02391049_74.jpg
# horse2zebra/trainB/n02391049_9918.jpg
# horse2zebra/trainB/n02391049_515.jpg
# horse2zebra/trainB/n02391049_2333.jpg
# horse2zebra/trainB/n02391049_1442.jpg
# horse2zebra/trainB/n02391049_272.jpg
# horse2zebra/trainB/n02391049_2889.jpg
# horse2zebra/trainB/n02391049_9675.jpg
# horse2zebra/trainB/n02391049_1163.jpg
# horse2zebra/trainB/n02391049_9002.jpg
# horse2zebra/trainB/n02391049_155.jpg
# horse2zebra/trainB/n02391049_3026.jpg
# horse2zebra/trainB/n02391049_11162.jpg
# horse2zebra/trainB/n02391049_2612.jpg
# horse2zebra/trainB/n02391049_713.jpg
# horse2zebra/trainB/n02391049_5679.jpg
# horse2zebra/trainB/n02391049_551.jpg
# horse2zebra/trainB/n02391049_1721.jpg
# horse2zebra/trainB/n02391049_8982.jpg
# horse2zebra/trainB/n02391049_2386.jpg
# horse2zebra/trainB/n02391049_487.jpg
# horse2zebra/trainB/n02391049_1495.jpg
# horse2zebra/trainB/n02391049_1738.jpg
# horse2zebra/trainB/n02391049_2782.jpg
# horse2zebra/trainB/n02391049_4564.jpg
# horse2zebra/trainB/n02391049_6184.jpg
# horse2zebra/trainB/n02391049_1891.jpg
# horse2zebra/trainB/n02391049_964.jpg
# horse2zebra/trainB/n02391049_1099.jpg
# horse2zebra/trainB/n02391049_8209.jpg
# horse2zebra/trainB/n02391049_3754.jpg
# horse2zebra/trainB/n02391049_7318.jpg
# horse2zebra/trainB/n02391049_2746.jpg
# horse2zebra/trainB/n02391049_847.jpg
# horse2zebra/trainB/n02391049_12.jpg
# horse2zebra/trainB/n02391049_9532.jpg
# horse2zebra/trainB/n02391049_4528.jpg
# horse2zebra/trainB/n02391049_2584.jpg
# horse2zebra/trainB/n02391049_685.jpg
# horse2zebra/trainB/n02391049_1855.jpg
# horse2zebra/trainB/n02391049_2665.jpg
# horse2zebra/trainB/n02391049_1378.jpg
# horse2zebra/trainB/n02391049_9055.jpg
# horse2zebra/trainB/n02391049_1459.jpg
# horse2zebra/trainB/n02391049_3079.jpg
# horse2zebra/trainB/n02391049_9136.jpg
# horse2zebra/trainB/n02391049_111.jpg
# horse2zebra/trainB/n02391049_2485.jpg
# horse2zebra/trainB/n02391049_2647.jpg
# horse2zebra/trainB/n02391049_6922.jpg
# horse2zebra/trainB/n02391049_1198.jpg
# horse2zebra/trainB/n02391049_865.jpg
# horse2zebra/trainB/n02391049_2926.jpg
# horse2zebra/trainB/n02391049_5356.jpg
# horse2zebra/trainB/n02391049_8902.jpg
# horse2zebra/trainB/n02391049_8182.jpg
# horse2zebra/trainB/n02391049_4069.jpg
# horse2zebra/trainB/n02391049_8425.jpg
# horse2zebra/trainB/n02391049_496.jpg
# horse2zebra/trainB/n02391049_102.jpg
# horse2zebra/trainB/n02391049_2476.jpg
# horse2zebra/trainB/n02391049_2638.jpg
# horse2zebra/trainB/n02391049_3844.jpg
# horse2zebra/trainB/n02391049_1189.jpg
# horse2zebra/trainB/n02391049_3682.jpg
# horse2zebra/trainB/n02391049_6517.jpg
# horse2zebra/trainB/n02391049_5383.jpg
# horse2zebra/trainB/n02391049_6436.jpg
# horse2zebra/trainB/n02391049_7048.jpg
# horse2zebra/trainB/n02391049_2593.jpg
# horse2zebra/trainB/n02391049_2836.jpg
# horse2zebra/trainB/n02391049_2674.jpg
# horse2zebra/trainB/n02391049_775.jpg
# horse2zebra/trainB/n02391049_5509.jpg
# horse2zebra/trainB/n02391049_10576.jpg
# horse2zebra/trainB/n02391049_10738.jpg
# horse2zebra/trainB/n02391049_379.jpg
# horse2zebra/trainB/n02391049_2197.jpg
# horse2zebra/trainB/n02391049_3088.jpg
# horse2zebra/trainB/n02391049_676.jpg
# horse2zebra/trainB/n02391049_1846.jpg
# horse2zebra/trainB/n02391049_2818.jpg
# horse2zebra/trainB/n02391049_2656.jpg
# horse2zebra/trainB/n02391049_757.jpg
# horse2zebra/trainB/n02391049_2098.jpg
# horse2zebra/trainB/n02391049_1288.jpg
# horse2zebra/trainB/n02391049_2935.jpg
# horse2zebra/trainB/n02391049_5527.jpg
# horse2zebra/trainB/n02391049_4474.jpg
# horse2zebra/trainB/n02391049_3187.jpg
# horse2zebra/trainB/n02391049_1567.jpg
# horse2zebra/trainB/n02391049_10837.jpg
# horse2zebra/trainB/n02391049_483.jpg
# horse2zebra/trainB/n02391049_5217.jpg
# horse2zebra/trainB/n02391049_249.jpg
# horse2zebra/trainB/n02391049_1419.jpg
# horse2zebra/trainB/n02391049_1095.jpg
# horse2zebra/trainB/n02391049_2229.jpg
# horse2zebra/trainB/n02391049_7071.jpg
# horse2zebra/trainB/n02391049_168.jpg
# horse2zebra/trainB/n02391049_924.jpg
# horse2zebra/trainB/n02391049_285.jpg
# horse2zebra/trainB/n02391049_2184.jpg
# horse2zebra/trainB/n02391049_2508.jpg
# horse2zebra/trainB/n02391049_7512.jpg
# horse2zebra/trainB/n02391049_3075.jpg
# horse2zebra/trainB/n02391049_2265.jpg
# horse2zebra/trainB/n02391049_9051.jpg
# horse2zebra/trainB/n02391049_8878.jpg
# horse2zebra/trainB/n02391049_87.jpg
# horse2zebra/trainB/n02391049_2805.jpg
# horse2zebra/trainB/n02391049_2481.jpg
# horse2zebra/trainB/n02391049_1752.jpg
# horse2zebra/trainB/n02391049_744.jpg
# horse2zebra/trainB/n02391049_3291.jpg
# horse2zebra/trainB/n02391049_2166.jpg
# horse2zebra/trainB/n02391049_267.jpg
# horse2zebra/trainB/n02391049_3219.jpg
# horse2zebra/trainB/n02391049_8061.jpg
# horse2zebra/trainB/n02391049_6081.jpg
# horse2zebra/trainB/n02391049_2922.jpg
# horse2zebra/trainB/n02391049_4704.jpg
# horse2zebra/trainB/n02391049_1158.jpg
# horse2zebra/trainB/n02391049_2049.jpg
# horse2zebra/trainB/n02391049_627.jpg
# horse2zebra/trainB/n02391049_2364.jpg
# horse2zebra/trainB/n02391049_465.jpg
# horse2zebra/trainB/n02391049_10824.jpg
# horse2zebra/trainB/n02391049_384.jpg
# horse2zebra/trainB/n02391049_3174.jpg
# horse2zebra/trainB/n02391049_5307.jpg
# horse2zebra/trainB/n02391049_1743.jpg
# horse2zebra/trainB/n02391049_8214.jpg
# horse2zebra/trainB/n02391049_2157.jpg
# horse2zebra/trainB/n02391049_9499.jpg
# horse2zebra/trainB/n02391049_1509.jpg
# horse2zebra/trainB/n02391049_8689.jpg
# horse2zebra/trainB/n02391049_10257.jpg
# horse2zebra/trainB/n02391049_1149.jpg
# horse2zebra/trainB/n02391049_3246.jpg
# horse2zebra/trainB/n02391049_7521.jpg
# horse2zebra/trainB/n02391049_1464.jpg
# horse2zebra/trainB/n02391049_9303.jpg
# horse2zebra/trainB/n02391049_3084.jpg
# horse2zebra/trainB/n02391049_2355.jpg
# horse2zebra/trainB/n02391049_4218.jpg
# horse2zebra/trainB/n02391049_3165.jpg
# horse2zebra/trainB/n02391049_915.jpg
# horse2zebra/trainB/n02391049_2814.jpg
# horse2zebra/trainB/n02391049_10239.jpg
# horse2zebra/trainB/n02391049_6216.jpg
# horse2zebra/trainB/n02391049_2571.jpg
# horse2zebra/trainB/n02391049_834.jpg
# horse2zebra/trainB/n02391049_2733.jpg
# horse2zebra/trainB/n02391049_10158.jpg
# horse2zebra/trainB/n02391049_3228.jpg
# horse2zebra/trainB/n02391049_7503.jpg
# horse2zebra/trainB/n02391049_276.jpg
# horse2zebra/trainB/n02391049_2337.jpg
# horse2zebra/trainB/n02391049_357.jpg
# horse2zebra/trainB/n02391049_2418.jpg
# horse2zebra/trainB/n02391049_1086.jpg
# horse2zebra/trainB/n02391049_11166.jpg
# horse2zebra/trainB/n02391049_9006.jpg
# horse2zebra/trainB/n02391049_10356.jpg
# horse2zebra/trainB/n02391049_7062.jpg
# horse2zebra/trainB/n02391049_3264.jpg
# horse2zebra/trainB/n02391049_3426.jpg
# horse2zebra/trainB/n02391049_5208.jpg
# horse2zebra/trainB/n02391049_474.jpg
# horse2zebra/trainB/n02391049_717.jpg
# horse2zebra/trainB/n02391049_2616.jpg
# horse2zebra/trainB/n02391049_1725.jpg
# horse2zebra/trainB/n02391049_1024.jpg
# horse2zebra/trainB/n02391049_8447.jpg
# ...
# horse2zebra/trainA/n02381460_203.jpg
# horse2zebra/trainA/n02381460_4476.jpg
# horse2zebra/trainA/n02381460_4395.jpg
# horse2zebra/trainA/n02381460_122.jpg
# horse2zebra/trainA/n02381460_5286.jpg
# horse2zebra/trainA/n02381460_993.jpg
# horse2zebra/trainA/n02381460_4674.jpg
# horse2zebra/trainA/n02381460_6294.jpg
# horse2zebra/trainA/n02381460_3783.jpg
# horse2zebra/trainA/n02381460_4917.jpg
# horse2zebra/trainA/n02381460_8157.jpg
# horse2zebra/trainA/n02381460_4593.jpg
# horse2zebra/trainA/n02381460_7905.jpg
# horse2zebra/trainA/n02381460_1686.jpg
# horse2zebra/trainA/n02381460_2496.jpg
# horse2zebra/trainA/n02381460_777.jpg
# horse2zebra/trainA/n02381460_4494.jpg
# horse2zebra/trainA/n02381460_939.jpg
# horse2zebra/trainA/n02381460_4737.jpg
# horse2zebra/trainA/n02381460_858.jpg
# horse2zebra/trainA/n02381460_2793.jpg
# horse2zebra/trainA/n02381460_3369.jpg
# horse2zebra/trainA/n02381460_7806.jpg
# horse2zebra/trainA/n02381460_1389.jpg
# horse2zebra/trainA/n02381460_908.jpg
# horse2zebra/trainA/n02381460_584.jpg
# horse2zebra/trainA/n02381460_1952.jpg
# horse2zebra/trainA/n02381460_4625.jpg
# horse2zebra/trainA/n02381460_7613.jpg
# horse2zebra/trainA/n02381460_2366.jpg
# horse2zebra/trainA/n02381460_1637.jpg
# horse2zebra/trainA/n02381460_2528.jpg
# horse2zebra/trainA/n02381460_863.jpg
# horse2zebra/trainA/n02381460_8306.jpg
# horse2zebra/trainA/n02381460_4661.jpg
# horse2zebra/trainA/n02381460_1439.jpg
# horse2zebra/trainA/n02381460_782.jpg
# horse2zebra/trainA/n02381460_5156.jpg
# horse2zebra/trainA/n02381460_1592.jpg
# horse2zebra/trainA/n02381460_1916.jpg
# horse2zebra/trainA/n02381460_386.jpg
# horse2zebra/trainA/n02381460_629.jpg
# horse2zebra/trainA/n02381460_2726.jpg
# horse2zebra/trainA/n02381460_1835.jpg
# horse2zebra/trainA/n02381460_2564.jpg
# horse2zebra/trainA/n02381460_5075.jpg
# horse2zebra/trainA/n02381460_764.jpg
# horse2zebra/trainA/n02381460_2627.jpg
# horse2zebra/trainA/n02381460_1736.jpg
# horse2zebra/trainA/n02381460_2465.jpg
# horse2zebra/trainA/n02381460_2708.jpg
# horse2zebra/trainA/n02381460_1493.jpg
# horse2zebra/trainA/n02381460_881.jpg
# horse2zebra/trainA/n02381460_728.jpg
# horse2zebra/trainA/n02381460_836.jpg
# horse2zebra/trainA/n02381460_674.jpg
# horse2zebra/trainA/n02381460_6335.jpg
# horse2zebra/trainA/n02381460_5525.jpg
# horse2zebra/trainA/n02381460_4472.jpg
# horse2zebra/trainA/n02381460_755.jpg
# horse2zebra/trainA/n02381460_3905.jpg
# horse2zebra/trainA/n02381460_7622.jpg
# horse2zebra/trainA/n02381460_2294.jpg
# horse2zebra/trainA/n02381460_3509.jpg
# horse2zebra/trainA/n02381460_1727.jpg
# horse2zebra/trainA/n02381460_278.jpg
# horse2zebra/trainA/n02381460_1484.jpg
# horse2zebra/trainA/n02381460_4751.jpg
# horse2zebra/trainA/n02381460_5804.jpg
# horse2zebra/trainA/n02381460_3149.jpg
# horse2zebra/trainA/n02381460_8153.jpg
# horse2zebra/trainA/n02381460_2339.jpg
# horse2zebra/trainA/n02381460_2177.jpg
# horse2zebra/trainA/n02381460_3383.jpg
# horse2zebra/trainA/n02381460_3707.jpg
# horse2zebra/trainA/n02381460_395.jpg
# horse2zebra/trainA/n02381460_1763.jpg
# horse2zebra/trainA/n02381460_1682.jpg
# horse2zebra/trainA/n02381460_476.jpg
# horse2zebra/trainA/n02381460_5408.jpg
# horse2zebra/trainA/n02381460_854.jpg
# horse2zebra/trainA/n02381460_2951.jpg
# horse2zebra/trainA/n02381460_1349.jpg
# horse2zebra/trainA/n02381460_3842.jpg
# horse2zebra/trainA/n02381460_4571.jpg
# horse2zebra/trainA/n02381460_935.jpg
# horse2zebra/trainA/n02381460_3365.jpg
# horse2zebra/trainA/n02381460_4094.jpg
# horse2zebra/trainA/n02381460_1583.jpg
# horse2zebra/trainA/n02381460_2474.jpg
# horse2zebra/trainA/n02381460_2555.jpg
# horse2zebra/trainA/n02381460_3329.jpg
# horse2zebra/trainA/n02381460_2276.jpg
# horse2zebra/trainA/n02381460_971.jpg
# horse2zebra/trainA/n02381460_2834.jpg
# horse2zebra/trainA/n02381460_3563.jpg
# horse2zebra/trainA/n02381460_2753.jpg
# horse2zebra/trainA/n02381460_4373.jpg
# horse2zebra/trainA/n02381460_1862.jpg
# horse2zebra/trainA/n02381460_117.jpg
# horse2zebra/trainA/n02381460_1798.jpg
# horse2zebra/trainA/n02381460_6964.jpg
# horse2zebra/trainA/n02381460_36.jpg
# horse2zebra/trainA/n02381460_1008.jpg
# horse2zebra/trainA/n02381460_7297.jpg
# horse2zebra/trainA/n02381460_2412.jpg
# horse2zebra/trainA/n02381460_2968.jpg
# horse2zebra/trainA/n02381460_153.jpg
# horse2zebra/trainA/n02381460_1521.jpg
# horse2zebra/trainA/n02381460_8944.jpg
# horse2zebra/trainA/n02381460_3222.jpg
# horse2zebra/trainA/n02381460_1602.jpg
# horse2zebra/trainA/n02381460_6289.jpg
# horse2zebra/trainA/n02381460_1044.jpg
# horse2zebra/trainA/n02381460_7495.jpg
# horse2zebra/trainA/n02381460_2016.jpg
# horse2zebra/trainA/n02381460_2788.jpg
# horse2zebra/trainA/n02381460_135.jpg
# horse2zebra/trainA/n02381460_1422.jpg
# horse2zebra/trainA/n02381460_1978.jpg
# horse2zebra/trainA/n02381460_5857.jpg
# horse2zebra/trainA/n02381460_8449.jpg
# horse2zebra/trainA/n02381460_6388.jpg
# horse2zebra/trainA/n02381460_4687.jpg
# horse2zebra/trainA/n02381460_6946.jpg
# horse2zebra/trainA/n02381460_7756.jpg
# horse2zebra/trainA/n02381460_1305.jpg
# horse2zebra/trainA/n02381460_2779.jpg
# horse2zebra/trainA/n02381460_2061.jpg
# horse2zebra/trainA/n02381460_1888.jpg
# horse2zebra/trainA/n02381460_2223.jpg
# horse2zebra/trainA/n02381460_4401.jpg
# horse2zebra/trainA/n02381460_2421.jpg
# horse2zebra/trainA/n02381460_4597.jpg
# horse2zebra/trainA/n02381460_1053.jpg
# horse2zebra/trainA/n02381460_1134.jpg
# horse2zebra/trainA/n02381460_306.jpg
# horse2zebra/trainA/n02381460_2403.jpg
# horse2zebra/trainA/n02381460_2878.jpg
# horse2zebra/trainA/n02381460_3051.jpg
# horse2zebra/trainA/n02381460_1035.jpg
# horse2zebra/trainA/n02381460_4975.jpg
# horse2zebra/trainA/n02381460_8179.jpg
# horse2zebra/trainA/n02381460_6397.jpg
# horse2zebra/trainA/n02381460_27.jpg
# horse2zebra/trainA/n02381460_2995.jpg
# horse2zebra/trainA/n02381460_979.jpg
# horse2zebra/trainA/n02381460_8575.jpg
# horse2zebra/trainA/n02381460_108.jpg
# horse2zebra/trainA/n02381460_2043.jpg
# horse2zebra/trainA/n02381460_5983.jpg
# horse2zebra/trainA/n02381460_3336.jpg
# horse2zebra/trainA/n02381460_186.jpg
# horse2zebra/trainA/n02381460_4146.jpg
# horse2zebra/trainA/n02381460_3417.jpg
# horse2zebra/trainA/n02381460_1635.jpg
# horse2zebra/trainA/n02381460_3255.jpg
# horse2zebra/trainA/n02381460_582.jpg
# horse2zebra/trainA/n02381460_3732.jpg
# horse2zebra/trainA/n02381460_2049.jpg
# horse2zebra/trainA/n02381460_4542.jpg
# horse2zebra/trainA/n02381460_825.jpg
# horse2zebra/trainA/n02381460_1158.jpg
# horse2zebra/trainA/n02381460_2643.jpg
# horse2zebra/trainA/n02381460_4425.jpg
# horse2zebra/trainA/n02381460_4263.jpg
# horse2zebra/trainA/n02381460_69.jpg
# horse2zebra/trainA/n02381460_384.jpg
# horse2zebra/trainA/n02381460_627.jpg
# horse2zebra/trainA/n02381460_7888.jpg
# horse2zebra/trainA/n02381460_6441.jpg
# horse2zebra/trainA/n02381460_2085.jpg
# horse2zebra/trainA/n02381460_1194.jpg
# horse2zebra/trainA/n02381460_528.jpg
# horse2zebra/trainA/n02381460_3354.jpg
# horse2zebra/trainA/n02381460_4407.jpg
# horse2zebra/trainA/n02381460_1734.jpg
# horse2zebra/trainA/n02381460_3192.jpg
# horse2zebra/trainA/n02381460_2706.jpg
# horse2zebra/trainA/n02381460_285.jpg
# horse2zebra/trainA/n02381460_1338.jpg
# horse2zebra/trainA/n02381460_726.jpg
# horse2zebra/trainA/n02381460_4999.jpg
# horse2zebra/trainA/n02381460_807.jpg
# horse2zebra/trainA/n02381460_3075.jpg
# horse2zebra/trainA/n02381460_249.jpg
# horse2zebra/trainA/n02381460_8241.jpg
# horse2zebra/trainA/n02381460_7512.jpg
# horse2zebra/trainA/n02381460_1563.jpg
# horse2zebra/trainA/n02381460_195.jpg
# horse2zebra/trainA/n02381460_519.jpg
# horse2zebra/trainA/n02381460_357.jpg
# horse2zebra/trainA/n02381460_276.jpg
# horse2zebra/trainA/n02381460_1482.jpg
# horse2zebra/trainA/n02381460_7305.jpg
# horse2zebra/trainA/n02381460_591.jpg
# horse2zebra/trainA/n02381460_6252.jpg
# horse2zebra/trainA/n02381460_4632.jpg
# horse2zebra/trainA/n02381460_3903.jpg
# horse2zebra/trainA/n02381460_2139.jpg
# horse2zebra/trainA/n02381460_4551.jpg
# horse2zebra/trainA/n02381460_5442.jpg
# horse2zebra/trainA/n02381460_834.jpg
# horse2zebra/trainA/n02381460_4434.jpg
# horse2zebra/trainA/n02381460_1761.jpg
# horse2zebra/trainA/n02381460_393.jpg
# horse2zebra/trainA/n02381460_717.jpg
# horse2zebra/trainA/n02381460_4515.jpg
# horse2zebra/trainA/n02381460_5406.jpg
# horse2zebra/trainA/n02381460_474.jpg
# horse2zebra/trainA/n02381460_3066.jpg
# horse2zebra/trainA/n02381460_3228.jpg
# horse2zebra/trainA/n02381460_5721.jpg
# horse2zebra/trainA/n02381460_1365.jpg
# horse2zebra/trainA/n02381460_3309.jpg
# horse2zebra/trainA/n02381460_1581.jpg
# horse2zebra/trainA/n02381460_3363.jpg
# horse2zebra/trainA/n02381460_1905.jpg
# horse2zebra/trainA/n02381460_1743.jpg
# horse2zebra/trainA/n02381460_8052.jpg
# horse2zebra/trainA/n02381460_933.jpg
# horse2zebra/trainA/n02381460_1266.jpg
# horse2zebra/trainA/n02381460_1347.jpg
# horse2zebra/trainA/n02381460_4731.jpg
# horse2zebra/trainA/n02381460_852.jpg
# horse2zebra/trainA/n02381460_1509.jpg
# horse2zebra/trainA/n02381460_1941.jpg
# horse2zebra/trainA/n02381460_1068.jpg
# horse2zebra/trainA/n02381460_654.jpg
# horse2zebra/trainA/n02381460_2751.jpg
# horse2zebra/trainA/n02381460_4371.jpg
# horse2zebra/trainA/n02381460_2517.jpg
# horse2zebra/trainA/n02381460_177.jpg
# horse2zebra/trainA/n02381460_1006.jpg
# horse2zebra/trainA/n02381460_4946.jpg
# horse2zebra/trainA/n02381460_986.jpg
# horse2zebra/trainA/n02381460_1796.jpg
# horse2zebra/trainA/n02381460_6089.jpg
# horse2zebra/trainA/n02381460_1402.jpg
# horse2zebra/trainA/n02381460_3659.jpg
# horse2zebra/trainA/n02381460_7493.jpg
# horse2zebra/trainA/n02381460_1204.jpg
# horse2zebra/trainA/n02381460_8708.jpg
# horse2zebra/trainA/n02381460_3299.jpg
# horse2zebra/trainA/n02381460_2014.jpg
# horse2zebra/trainA/n02381460_5396.jpg
# horse2zebra/trainA/n02381460_788.jpg
# horse2zebra/trainA/n02381460_7178.jpg
# horse2zebra/trainA/n02381460_5558.jpg
# horse2zebra/trainA/n02381460_4748.jpg
# horse2zebra/trainA/n02381460_869.jpg
# horse2zebra/trainA/n02381460_3857.jpg
# horse2zebra/trainA/n02381460_9095.jpg
# horse2zebra/trainA/n02381460_1105.jpg
# horse2zebra/trainA/n02381460_1501.jpg
# horse2zebra/trainA/n02381460_6782.jpg
# horse2zebra/trainA/n02381460_6944.jpg
# horse2zebra/trainA/n02381460_3398.jpg
# horse2zebra/trainA/n02381460_5891.jpg
# horse2zebra/trainA/n02381460_2032.jpg
# horse2zebra/trainA/n02381460_7754.jpg
# horse2zebra/trainA/n02381460_3956.jpg
# horse2zebra/trainA/n02381460_968.jpg
# horse2zebra/trainA/n02381460_4766.jpg
# horse2zebra/trainA/n02381460_5819.jpg
# horse2zebra/trainA/n02381460_4928.jpg
# horse2zebra/trainA/n02381460_331.jpg
# horse2zebra/trainA/n02381460_3875.jpg
# horse2zebra/trainA/n02381460_5927.jpg
# horse2zebra/trainA/n02381460_9167.jpg
# horse2zebra/trainA/n02381460_601.jpg
# horse2zebra/trainA/n02381460_4397.jpg
# horse2zebra/trainA/n02381460_4991.jpg
# horse2zebra/trainA/n02381460_1769.jpg
# horse2zebra/trainA/n02381460_1051.jpg
# horse2zebra/trainA/n02381460_1132.jpg
# horse2zebra/trainA/n02381460_2023.jpg
# horse2zebra/trainA/n02381460_5729.jpg
# horse2zebra/trainA/n02381460_322.jpg
# horse2zebra/trainA/n02381460_61.jpg
# horse2zebra/trainA/n02381460_5864.jpg
# horse2zebra/trainA/n02381460_6836.jpg
# horse2zebra/trainA/n02381460_3211.jpg
# horse2zebra/trainA/n02381460_223.jpg
# horse2zebra/trainA/n02381460_2795.jpg
# horse2zebra/trainA/n02381460_8735.jpg
# horse2zebra/trainA/n02381460_6476.jpg
# horse2zebra/trainA/n02381460_3965.jpg
# horse2zebra/trainA/n02381460_421.jpg
# horse2zebra/trainA/n02381460_4856.jpg
# horse2zebra/trainA/n02381460_1639.jpg
# horse2zebra/trainA/n02381460_2449.jpg
# horse2zebra/trainA/n02381460_1002.jpg
# horse2zebra/trainA/n02381460_7219.jpg
# horse2zebra/trainA/n02381460_4465.jpg
# horse2zebra/trainA/n02381460_4348.jpg
# horse2zebra/trainA/n02381460_3619.jpg
# horse2zebra/trainA/n02381460_1675.jpg
# horse2zebra/trainA/n02381460_7651.jpg
# horse2zebra/trainA/n02381460_6922.jpg
# horse2zebra/trainA/n02381460_4429.jpg
# horse2zebra/trainA/n02381460_8704.jpg
# horse2zebra/trainA/n02381460_2089.jpg
# horse2zebra/trainA/n02381460_784.jpg
# horse2zebra/trainA/n02381460_4663.jpg
# horse2zebra/trainA/n02381460_2548.jpg
# horse2zebra/trainA/n02381460_1101.jpg
# horse2zebra/trainA/n02381460_4168.jpg
# horse2zebra/trainA/n02381460_3358.jpg
# horse2zebra/trainA/n02381460_4726.jpg
# horse2zebra/trainA/n02381460_4483.jpg
# horse2zebra/trainA/n02381460_3754.jpg
# horse2zebra/trainA/n02381460_4645.jpg
# horse2zebra/trainA/n02381460_5374.jpg
# horse2zebra/trainA/n02381460_1855.jpg
# horse2zebra/trainA/n02381460_4528.jpg
# horse2zebra/trainA/n02381460_3394.jpg
# horse2zebra/trainA/n02381460_4447.jpg
# horse2zebra/trainA/n02381460_3556.jpg
# horse2zebra/trainA/n02381460_1774.jpg
# horse2zebra/trainA/n02381460_2269.jpg
# horse2zebra/trainA/n02381460_1297.jpg
# horse2zebra/trainA/n02381460_1486.jpg
# horse2zebra/trainA/n02381460_5761.jpg
# horse2zebra/trainA/n02381460_2539.jpg
# horse2zebra/trainA/n02381460_1648.jpg
# horse2zebra/trainA/n02381460_4159.jpg
# horse2zebra/trainA/n02381460_199.jpg
# horse2zebra/trainA/n02381460_1567.jpg
# horse2zebra/trainA/n02381460_1011.jpg
# horse2zebra/trainA/n02381460_8515.jpg
# horse2zebra/trainA/n02381460_3664.jpg
# horse2zebra/trainA/n02381460_676.jpg
# horse2zebra/trainA/n02381460_4474.jpg
# horse2zebra/trainA/n02381460_919.jpg
# horse2zebra/trainA/n02381460_595.jpg
# horse2zebra/trainA/n02381460_757.jpg
# horse2zebra/trainA/n02381460_7903.jpg
# horse2zebra/trainA/n02381460_2575.jpg
# horse2zebra/trainA/n02381460_4195.jpg
# horse2zebra/trainA/n02381460_3466.jpg
# horse2zebra/trainA/n02381460_5167.jpg
# horse2zebra/trainA/n02381460_559.jpg
# horse2zebra/trainA/n02381460_4276.jpg
# horse2zebra/trainA/n02381460_6373.jpg
# horse2zebra/trainA/n02381460_1288.jpg
# horse2zebra/trainA/n02381460_9127.jpg
# horse2zebra/trainA/n02381460_2179.jpg
# horse2zebra/trainA/n02381460_3286.jpg
# horse2zebra/trainA/n02381460_1666.jpg
# horse2zebra/trainA/n02381460_4096.jpg
# horse2zebra/trainA/n02381460_1909.jpg
# horse2zebra/trainA/n02381460_2476.jpg
# horse2zebra/trainA/n02381460_856.jpg
# horse2zebra/trainA/n02381460_2953.jpg
# horse2zebra/trainA/n02381460_1981.jpg
# horse2zebra/trainA/n02381460_4816.jpg
# horse2zebra/trainA/n02381460_5545.jpg
# horse2zebra/trainA/n02381460_2872.jpg
# horse2zebra/trainA/n02381460_7165.jpg
# horse2zebra/trainA/n02381460_102.jpg
# horse2zebra/trainA/n02381460_5266.jpg
# horse2zebra/trainA/n02381460_8812.jpg
# horse2zebra/trainA/n02381460_2755.jpg
# horse2zebra/trainA/n02381460_4456.jpg
# horse2zebra/trainA/n02381460_4294.jpg
# horse2zebra/trainA/n02381460_739.jpg
# horse2zebra/trainA/n02381460_9064.jpg
# horse2zebra/trainA/n02381460_4771.jpg
# horse2zebra/trainA/n02381460_1387.jpg
# horse2zebra/trainA/n02381460_4151.jpg
# horse2zebra/trainA/n02381460_3897.jpg
# horse2zebra/trainA/n02381460_1721.jpg
# horse2zebra/trainA/n02381460_4788.jpg
# horse2zebra/trainA/n02381460_2612.jpg
# horse2zebra/trainA/n02381460_3107.jpg
# horse2zebra/trainA/n02381460_1082.jpg
# horse2zebra/trainA/n02381460_8586.jpg
# horse2zebra/trainA/n02381460_7695.jpg
# horse2zebra/trainA/n02381460_911.jpg
# horse2zebra/trainA/n02381460_1127.jpg
# horse2zebra/trainA/n02381460_1208.jpg
# horse2zebra/trainA/n02381460_2414.jpg
# horse2zebra/trainA/n02381460_1361.jpg
# horse2zebra/trainA/n02381460_1523.jpg
# horse2zebra/trainA/n02381460_155.jpg
# horse2zebra/trainA/n02381460_236.jpg
# horse2zebra/trainA/n02381460_7398.jpg
# horse2zebra/trainA/n02381460_452.jpg
# horse2zebra/trainA/n02381460_4331.jpg
# horse2zebra/trainA/n02381460_1028.jpg
# horse2zebra/trainA/n02381460_1901.jpg
# horse2zebra/trainA/n02381460_4412.jpg
# horse2zebra/trainA/n02381460_1262.jpg
# horse2zebra/trainA/n02381460_1307.jpg
# horse2zebra/trainA/n02381460_1226.jpg
# horse2zebra/trainA/n02381460_1703.jpg
# horse2zebra/trainA/n02381460_3512.jpg
# horse2zebra/trainA/n02381460_1019.jpg
# horse2zebra/trainA/n02381460_4403.jpg
# horse2zebra/trainA/n02381460_1334.jpg
# horse2zebra/trainA/n02381460_8838.jpg
# horse2zebra/trainA/n02381460_128.jpg
# horse2zebra/trainA/n02381460_2225.jpg
# horse2zebra/trainA/n02381460_2306.jpg
# horse2zebra/trainA/n02381460_6975.jpg
# horse2zebra/trainA/n02381460_2027.jpg
# horse2zebra/trainA/n02381460_803.jpg
# horse2zebra/trainA/n02381460_5411.jpg
# horse2zebra/trainA/n02381460_2261.jpg
# horse2zebra/trainA/n02381460_4502.jpg
# horse2zebra/trainA/n02381460_3611.jpg
# horse2zebra/trainA/n02381460_461.jpg
# horse2zebra/trainA/n02381460_4977.jpg
# horse2zebra/trainA/n02381460_1037.jpg
# horse2zebra/trainA/n02381460_2799.jpg
# horse2zebra/trainA/n02381460_2045.jpg
# horse2zebra/trainA/n02381460_6876.jpg
# horse2zebra/trainA/n02381460_8577.jpg
# horse2zebra/trainA/n02381460_902.jpg
# horse2zebra/trainA/n02381460_182.jpg
# horse2zebra/trainA/n02381460_506.jpg
# horse2zebra/trainA/n02381460_4779.jpg
